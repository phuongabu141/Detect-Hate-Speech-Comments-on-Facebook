# %% [markdown]
# ![image.png](data:image/png;base64,...)
# ---

# %%
pip install pyvi
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pyvi
#   Downloading pyvi-0.1.1-py2.py3-none-any.whl (8.5 MB)
#      |████████████████████████████████| 8.5 MB 24.7 MB/s
# Collecting sklearn-crfsuite
#   Downloading sklearn_crfsuite-0.3.6-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from pyvi) (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.21.6)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (1.4.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->pyvi) (3.1.0)
# Requirement already satisfied: tqdm>=2.0 in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (4.64.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (1.15.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from sklearn-crfsuite->pyvi) (0.8.9)
# Collecting python-crfsuite>=0.8.3
#   Downloading python_crfsuite-0.9.8-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (965 kB)
#      |████████████████████████████████| 965 kB 40.7 MB/s
# Installing collected packages: python-crfsuite, sklearn-crfsuite, pyvi
# Successfully installed python-crfsuite-0.9.8 pyvi-0.1.1 sklearn-crfsuite-0.3.6

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Environment Preparation**

# %% [markdown]
# **Install Java 8**
#
# Run the cell on the **Google Colab** to install jdk 1.8.
#
# **Note:** if you run this notebook on your computer, root permission is required when running the cell to install Java 8. (You may ignore this cell if Java 8 has already been set up in your computer).

# %%
# Install jdk8
# !apt-get install openjdk-8-jdk-headless -qq > /dev/null
import os
# Set environment variable JAVA_HOME.
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-8-openjdk-amd64"
# !update-alternatives --set java /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java
# !java -version
# Out:
# update-alternatives: using /usr/lib/jvm/java-8-openjdk-amd64/jre/bin/java to provide /usr/bin/java (java) in manual mode
# openjdk version "1.8.0_312"
# OpenJDK Runtime Environment (build 1.8.0_312-8u312-b07-0ubuntu1~18.04-b07)
# OpenJDK 64-Bit Server VM (build 25.312-b07, mixed mode)

# %% [markdown]
# **Install BigDL Orca**
#
# You can install the latest pre-release version using `pip install --pre --upgrade bigdl-orca`.

# %%
# Install latest pre-release version of BigDL Orca 
# Installing BigDL Orca from pip will automatically install pyspark, bigdl, and their dependencies.
# !pip install --pre --upgrade bigdl-orca[ray]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bigdl-orca[ray]
#   Downloading bigdl_orca-2.1.0b20220701-py3-none-manylinux1_x86_64.whl (23.9 MB)
#      |████████████████████████████████| 23.9 MB 2.0 MB/s
# Collecting bigdl-tf==0.14.0.dev1
#   Downloading bigdl_tf-0.14.0.dev1-py3-none-manylinux2010_x86_64.whl (71.0 MB)
#      |████████████████████████████████| 71.0 MB 275 bytes/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from bigdl-orca[ray]) (3.7.1)
# Collecting bigdl-dllib==2.1.0b20220701
#   Downloading bigdl_dllib-2.1.0b20220701-py3-none-manylinux1_x86_64.whl (51.8 MB)
#      |████████████████████████████████| 51.8 MB 1.5 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from bigdl-orca[ray]) (21.3)
# Requirement already satisfied: pyzmq in /usr/local/lib/python3.7/dist-packages (from bigdl-orca[ray]) (23.1.0)
# Collecting bigdl-math==0.14.0.dev1
#   Downloading bigdl_math-0.14.0.dev1-py3-none-manylinux2010_x86_64.whl (35.4 MB)
#      |████████████████████████████████| 35.4 MB 466 kB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.7/dist-packages (from bigdl-orca[ray]) (5.4.8)
# Collecting ray[default]==1.9.2
#   Downloading ray-1.9.2-cp37-cp37m-manylinux2014_x86_64.whl (57.6 MB)
#      |████████████████████████████████| 57.6 MB 1.3 MB/s
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting aiohttp==3.8.1
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 40.7 MB/s
# Collecting aioredis==1.3.1
#   Downloading aioredis-1.3.1-py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.9 MB/s
# Collecting async-timeout==4.0.1
#   Downloading async_timeout-4.0.1-py3-none-any.whl (5.7 kB)
# Collecting hiredis==2.0.0
#   Downloading hiredis-2.0.0-cp37-cp37m-manylinux2010_x86_64.whl (85 kB)
#      |████████████████████████████████| 85 kB 3.9 MB/s
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca[ray]) (4.1.1)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 56.0 MB/s
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca[ray]) (2.0.12)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 52.2 MB/s
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 3.9 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp==3.8.1->bigdl-orca[ray]) (21.4.0)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting bigdl-core==2.1.0b20220321
#   Downloading bigdl_core-2.1.0b20220321-py3-none-manylinux2010_x86_64.whl (51.0 MB)
#      |████████████████████████████████| 51.0 MB 96 kB/s
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==2.1.0b20220701->bigdl-orca[ray]) (1.15.0)
# Collecting conda-pack==0.3.1
#   Downloading conda_pack-0.3.1-py2.py3-none-any.whl (27 kB)
# Requirement already satisfied: numpy>=1.19.5 in /usr/local/lib/python3.7/dist-packages (from bigdl-dllib==2.1.0b20220701->bigdl-orca[ray]) (1.21.6)
# Collecting pyspark==2.4.6
#   Downloading pyspark-2.4.6.tar.gz (218.4 MB)
#      |████████████████████████████████| 218.4 MB 51 kB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from conda-pack==0.3.1->bigdl-dllib==2.1.0b20220701->bigdl-orca[ray]) (57.4.0)
# Collecting py4j==0.10.7
#   Downloading py4j-0.10.7-py2.py3-none-any.whl (197 kB)
#      |████████████████████████████████| 197 kB 65.6 MB/s
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (7.1.2)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.4-py3-none-any.whl (246 kB)
#      |████████████████████████████████| 246 kB 64.3 MB/s
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (1.0.4)
# Requirement already satisfied: protobuf>=3.15.3 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (3.17.3)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (3.13)
# Requirement already satisfied: grpcio>=1.28.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (1.46.3)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (4.3.3)
# Collecting opencensus
#   Downloading opencensus-0.9.0-py2.py3-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 69.6 MB/s
# Requirement already satisfied: smart-open in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (5.2.1)
# Collecting py-spy>=0.2.0
#   Downloading py_spy-0.4.0_dev2-py2.py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.whl (2.9 MB)
#      |████████████████████████████████| 2.9 MB 29.9 MB/s
# Requirement already satisfied: prometheus-client>=0.7.1 in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (0.14.1)
# Collecting colorful
#   Downloading colorful-0.6.0a1-py2.py3-none-any.whl (202 kB)
#      |████████████████████████████████| 202 kB 74.0 MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from ray[default]==1.9.2->bigdl-orca[ray]) (2.23.0)
# Collecting aiohttp-cors
#   Downloading aiohttp_cors-0.7.0-py3-none-any.whl (27 kB)
# Collecting gpustat>=1.0.0b1
#   Downloading gpustat-1.0.0b1.tar.gz (82 kB)
#      |████████████████████████████████| 82 kB 244 kB/s
# Collecting nvidia-ml-py3>=7.352.0
#   Downloading nvidia-ml-py3-7.352.0.tar.gz (19 kB)
# Collecting blessed>=1.17.1
#   Downloading blessed-1.19.1-py2.py3-none-any.whl (58 kB)
#      |████████████████████████████████| 58 kB 3.6 MB/s
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.7/dist-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]==1.9.2->bigdl-orca[ray]) (0.2.5)
# Requirement already satisfied: importlib-metadata>=1.0 in /usr/local/lib/python3.7/dist-packages (from redis>=3.5.0->ray[default]==1.9.2->bigdl-orca[ray]) (4.11.4)
# Collecting redis>=3.5.0
#   Downloading redis-4.3.3-py3-none-any.whl (244 kB)
#      |████████████████████████████████| 244 kB 65.7 MB/s
#   Downloading redis-4.3.2-py3-none-any.whl (244 kB)
#      |████████████████████████████████| 244 kB 67.7 MB/s
#   Downloading redis-4.3.1-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 57.8 MB/s
#   Downloading redis-4.3.0-py3-none-any.whl (241 kB)
#      |████████████████████████████████| 241 kB 53.9 MB/s
#   Downloading redis-4.2.2-py3-none-any.whl (226 kB)
#      |████████████████████████████████| 226 kB 50.6 MB/s
#   Downloading redis-4.2.1-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 57.1 MB/s
#   Downloading redis-4.2.0-py3-none-any.whl (225 kB)
#      |████████████████████████████████| 225 kB 54.5 MB/s
#   Downloading redis-4.2.0rc3-py3-none-any.whl (224 kB)
#      |████████████████████████████████| 224 kB 57.7 MB/s
#   Downloading redis-4.2.0rc2-py3-none-any.whl (223 kB)
#      |████████████████████████████████| 223 kB 47.2 MB/s
#   Downloading redis-4.2.0rc1-py3-none-any.whl (220 kB)
#      |████████████████████████████████| 220 kB 56.5 MB/s
#   Downloading redis-4.1.4-py3-none-any.whl (175 kB)
#      |████████████████████████████████| 175 kB 55.1 MB/s
# Collecting deprecated>=1.2.3
#   Downloading Deprecated-1.2.13-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.7/dist-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[default]==1.9.2->bigdl-orca[ray]) (1.14.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.0->redis>=3.5.0->ray[default]==1.9.2->bigdl-orca[ray]) (3.8.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->bigdl-orca[ray]) (3.0.9)
# Requirement already satisfied: idna>=2.0 in /usr/local/lib/python3.7/dist-packages (from yarl<2.0,>=1.0->aiohttp==3.8.1->bigdl-orca[ray]) (2.10)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.9.2->bigdl-orca[ray]) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema->ray[default]==1.9.2->bigdl-orca[ray]) (5.7.1)
# Collecting opencensus-context>=0.1.2
#   Downloading opencensus_context-0.2.dev0-py2.py3-none-any.whl (4.5 kB)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (1.31.6)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (2022.1)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (1.56.2)
# Requirement already satisfied: google-auth<2.0dev,>=1.25.0 in /usr/local/lib/python3.7/dist-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (1.35.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (4.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (4.2.4)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (0.2.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]==1.9.2->bigdl-orca[ray]) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.2->bigdl-orca[ray]) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.2->bigdl-orca[ray]) (2022.6.15)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->ray[default]==1.9.2->bigdl-orca[ray]) (1.24.3)
# Building wheels for collected packages: pyspark, gpustat, nvidia-ml-py3
#   Building wheel for pyspark (setup.py) ... done
#   Created wheel for pyspark: filename=pyspark-2.4.6-py2.py3-none-any.whl size=218814407 sha256=47c26d2324fd7b727deb4b78cc595930c0f9c9a25692a33e4fe1b75f19fba718
#   Stored in directory: /root/.cache/pip/wheels/f1/42/b0/ba397759613f4feb1611021a2503e60e344e546671b2ae04f8
#   Building wheel for gpustat (setup.py) ... done
#   Created wheel for gpustat: filename=gpustat-1.0.0b1-py3-none-any.whl size=15979 sha256=3cc561955465cfc9014be246d0c57956047e2d04ec7c0f80eafc17b705fc723e
#   Stored in directory: /root/.cache/pip/wheels/1a/16/e2/3e2437fba4c4b6a97a97bd96fce5d14e66cff5c4966fb1cc8c
#   Building wheel for nvidia-ml-py3 (setup.py) ... done
#   Created wheel for nvidia-ml-py3: filename=nvidia_ml_py3-7.352.0-py3-none-any.whl size=19190 sha256=011d2f9b46dd9f6d18d92e3f8cbeb8145db24ca9a2800dddfbaf929c8600353b
#   Stored in directory: /root/.cache/pip/wheels/df/99/da/c34f202dc8fd1dffd35e0ecf1a7d7f8374ca05fbcbaf974b83
# Successfully built pyspark gpustat nvidia-ml-py3
# Installing collected packages: multidict, frozenlist, yarl, py4j, deprecated, asynctest, async-timeout, aiosignal, redis, pyspark, opencensus-context, nvidia-ml-py3, hiredis, conda-pack, blessed, bigdl-core, aiohttp, ray, py-spy, opencensus, gpustat, colorful, bigdl-tf, bigdl-math, bigdl-dllib, aioredis, aiohttp-cors, setproctitle, bigdl-orca
# Successfully installed aiohttp-3.8.1 aiohttp-cors-0.7.0 aioredis-1.3.1 aiosignal-1.2.0 async-timeout-4.0.1 asynctest-0.13.0 bigdl-core-2.1.0b20220321 bigdl-dllib-2.1.0b20220701 bigdl-math-0.14.0.dev1 bigdl-orca-2.1.0b20220701 bigdl-tf-0.14.0.dev1 blessed-1.19.1 colorful-0.6.0a1 conda-pack-0.3.1 deprecated-1.2.13 frozenlist-1.3.0 gpustat-1.0.0b1 hiredis-2.0.0 multidict-6.0.2 nvidia-ml-py3-7.352.0 opencensus-0.9.0 opencensus-context-0.2.dev0 py-spy-0.4.0.dev2 py4j-0.10.7 pyspark-2.4.6 ray-1.9.2 redis-4.1.4 setproctitle-1.2.3 yarl-1.7.2

# %% [markdown]
# ## **Distributed TensorFlow 2 using Orca APIs**
#
# In this guide we will describe how to scale out TensorFlow 2 programs using Orca in 4 simple steps.

# %%
# import necesary libraries and modules
import argparse

from bigdl.orca import init_orca_context, stop_orca_context
from bigdl.orca import OrcaContext

# %% [markdown]
# ### **Step 1: Init Orca Context**

# %%
# recommended to set it to True when running BigDL in Jupyter notebook 
OrcaContext.log_output = True # (this will display terminal's stdout and stderr in the Jupyter notebook).

cluster_mode = "local"

if cluster_mode == "local":  
    init_orca_context(cluster_mode="local", cores=1) # run in local mode
elif cluster_mode == "k8s":  
    init_orca_context(cluster_mode="k8s", num_nodes=2, cores=2) # run on K8s cluster
elif cluster_mode == "yarn":  
    init_orca_context(cluster_mode="yarn-client", num_nodes=2, cores=2) # run on Hadoop YARN cluster
# Out:
# Initializing orca context
# Current pyspark location is : /usr/local/lib/python3.7/dist-packages/pyspark/__init__.py
# Start to getOrCreate SparkContext
# pyspark_submit_args is:  --driver-class-path /usr/local/lib/python3.7/dist-packages/bigdl/share/core/lib/all-2.1.0-20220314.094552-2.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/orca/lib/bigdl-orca-spark_2.4.6-2.1.0-SNAPSHOT-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/dllib/lib/bigdl-dllib-spark_2.4.6-2.1.0-SNAPSHOT-jar-with-dependencies.jar --driver-class-path /usr/local/lib/python3.7/dist-packages/bigdl/share/core/lib/all-2.1.0-20220314.094552-2.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/orca/lib/bigdl-orca-spark_2.4.6-2.1.0-SNAPSHOT-jar-with-dependencies.jar:/usr/local/lib/python3.7/dist-packages/bigdl/share/dllib/lib/bigdl-dllib-spark_2.4.6-2.1.0-SNAPSHOT-jar-with-dependencies.jar pyspark-shell
# Successfully got a SparkContext

# %% [markdown]
# This is the only place where you need to specify local or distributed mode. View [Orca Context](https://bigdl.readthedocs.io/en/latest/doc/Orca/Overview/orca-context.html) for more details.
#
# **Note**: You should export HADOOP_CONF_DIR=/path/to/hadoop/conf/dir when you run on Hadoop YARN cluster.

# %% [markdown]
# ### **Step 2: Define the Model**
#
# You can then define the Keras model in the *Creator Function* using the standard TensroFlow 2 APIs.

# %%
import pandas as pd 
import numpy as np 

DATA = '/content/drive/MyDrive/Colab/BigData/vihsd/train.csv'
DEV_DATA = '/content/drive/MyDrive/Colab/BigData/vihsd/dev.csv'
TEST_DATA = '/content/drive/MyDrive/Colab/BigData/vihsd/test.csv'

# read data
train_data = pd.read_csv(DATA)
dev_data = pd.read_csv(DEV_DATA)
test_data = pd.read_csv(TEST_DATA)

X_train = train_data['free_text']
y_train = train_data['label_id'].values

X_dev = dev_data['free_text']
y_dev = dev_data['label_id'].values

X_test = test_data['free_text']
y_test = test_data['label_id'].values

# %%
import re
import pandas as pd 
import numpy as np
from pyvi.ViTokenizer import ViTokenizer

STOPWORDS = '/content/drive/MyDrive/Colab/BigData/vietnamese-stopwords-dash.txt'
with open(STOPWORDS, "r") as ins:
    stopwords = []
    for line in ins:
        dd = line.strip('\n').strip('\"')
        stopwords.append(dd)
    stopwords = set(stopwords)

def filter_stop_words(train_sentences, stop_words):
    new_sent = [word for word in train_sentences.split() if word not in stop_words]
    train_sentences = ' '.join(new_sent)
        
    return train_sentences

def deEmojify(text):
    regrex_pattern = re.compile(pattern = "["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           "]+", flags = re.UNICODE)
    return regrex_pattern.sub(r'',text)

def preprocess(text, tokenized = True, lowercased = True):
    text = ViTokenizer.tokenize(text) if tokenized else text
    text = filter_stop_words(text, stopwords)
    text = deEmojify(text)
    text = text.lower() if lowercased else text
    return str(text)

# --------------TRICH XUAT DAC TRUNG -------------------------
def pre_process_features(X, y, tokenized = True, lowercased = True):
    X = [preprocess(str(p), tokenized = tokenized, lowercased = lowercased) for p in list(X)]
    for idx, ele in enumerate(X):
        if not ele:
            np.delete(X, idx)
            np.delete(y, idx)
    return X, y


train_X, train_y = pre_process_features(X_train, y_train, tokenized=True, lowercased = True)
dev_X, dev_y = pre_process_features(X_dev, y_dev, tokenized=True, lowercased = True)
test_X, test_y = pre_process_features(X_test, y_test, tokenized=True, lowercased = True)

# %%
from tensorflow import keras
from tensorflow.keras.preprocessing import text, sequence
from tensorflow.keras.utils import to_categorical
import pickle

EMBEDDING_FILE = '/content/drive/MyDrive/FakeCommentDetection/cc.vi.300.vec'
MODEL_FILE = '/content/drive/MyDrive/Colab/BigData/model/GRU_model.h5'

# def make_featues(X, y, tokenizer, is_one_hot_label=True):
#     X = tokenizer.texts_to_sequences(X)
#     X = sequence.pad_sequences(X, maxlen=sequence_length)
#     if is_one_hot_label: 
#         y = to_categorical(y, num_classes=3)

#     return X, y

vocabulary_size = 10000 
sequence_length = 100

embedding_dim = 300
batch_size = 256
epochs = 40
drop = 0.5

embeddings_index = {}
with open(EMBEDDING_FILE, encoding='utf8') as f:
    for line in f:
        values = line.rstrip().rsplit(' ')
        word = values[0]
        coefs = np.asarray(values[1:], dtype='float32')
        embeddings_index[word] = coefs

tokenizer = text.Tokenizer(lower=False, filters='!"#$%&()*+,-./:;<=>?@[\\]^`{|}~\t\n')
tokenizer.fit_on_texts(train_X)
# with open('/content/drive/MyDrive/Colab/BigData/tokenizer.pickle', 'wb') as handle:
#     pickle.dump(tokenizer, handle, protocol=pickle.HIGHEST_PROTOCOL)

# --------------LOAD WORD EMBEDDING-------------------------
word_index = tokenizer.word_index
# num_words = min(vocabulary_size, len(word_index) + 1)
num_words = len(word_index) + 1
embedding_matrix = np.zeros((num_words, embedding_dim))

for word, i in word_index.items():
    if i >= vocabulary_size:
        continue

    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector

# train_X, train_y = make_featues(train_X, train_y, tokenizer)
# dev_X, dev_y = make_featues(dev_X, dev_y, tokenizer)
# test_X, test_y = make_featues(test_X, test_y, tokenizer, is_one_hot_label=True)

# %%
import pandas as pd 
import numpy as np 
import re
import pickle

import seaborn as sn
import matplotlib.pyplot as plt

from tensorflow import keras
from keras.layers import Dense, Input, Bidirectional, GRU, LSTM
from keras.layers import Embedding, Reshape, Flatten, Dropout, Concatenate, Conv2D, MaxPool2D
from keras.preprocessing import text, sequence
from keras.layers import GlobalMaxPooling1D, GlobalAveragePooling1D, concatenate, SpatialDropout1D
from keras.models import Model
from keras import backend as K
from tensorflow.keras.utils import to_categorical
from sklearn.metrics import f1_score, confusion_matrix, accuracy_score
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit

from pyvi.ViTokenizer import ViTokenizer

# %% [markdown]
# #### **GRU**

# %%
def model_creator(config):
    import tensorflow as tf

    input = Input(shape=(sequence_length,))
    x = Embedding(num_words, embedding_dim, weights=[embedding_matrix])(input)
    x = SpatialDropout1D(0.2)(x)
    x = Bidirectional(GRU(80, return_sequences=True))(x)
    avg_pool = GlobalAveragePooling1D()(x)
    max_pool = GlobalMaxPooling1D()(x)
    conc = concatenate([avg_pool, max_pool])
    output = Dense(3, activation="softmax")(conc)

    # this creates a model that includes
    model = Model(inputs=input, outputs=output)
    adam = Adam(lr=1e-4, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

    model.compile(optimizer=adam, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

# %% [markdown]
# ### **Step 3: Define Train Dataset**
#
# You can define the dataset in the _Creator Function_ using standard [tf.data.Dataset](https://www.tensorflow.org/api_docs/python/tf/data/Dataset) APIs.

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql import functions as f
from pyspark.sql import types as t
from pyspark.sql.types import StructType,StructField, StringType, IntegerType

spark = SparkSession.builder.appName("Sentiment_Model").config("spark.executor.memory","6g").getOrCreate()

# %%
df_train = spark.read.format("csv").options(header=True, inferSchema=True).option("quote", "\"").option("escape", "\"").csv(DATA)
df_dev = spark.read.format("csv").options(header=True, inferSchema=True).option("quote", "\"").option("escape", "\"").csv(DEV_DATA)
df_test = spark.read.format("csv").options(header=True, inferSchema=True).option("quote", "\"").option("escape", "\"").csv(TEST_DATA)

# %%
def make_featues_text(X):
    text = str(X).strip().replace('"', '')
    X = tokenizer.texts_to_sequences([X])
    X = sequence.pad_sequences(X, maxlen=sequence_length)
    return X[0].tolist()

preprocess_udf = f.udf(preprocess, t.StringType())
make_featues_text_udf = f.udf(make_featues_text, t.ArrayType(t.IntegerType()))
make_label_udf = f.udf(lambda v: to_categorical(v, num_classes=3).tolist(), t.ArrayType(t.DoubleType()))

user_regex = r"(@\w{1,15})"
hashtag_replace_regex = "#(\w{1,})"
url_regex = r"((https?|ftp|file):\/{2,3})+([-\w+&@#/%=~|$?!:,.]*)|(www.)+([-\w+&@#/%=~|$?!:,.]*)"
email_regex = r"[\w.-]+@[\w.-]+\.[a-zA-Z]{1,}"

def pre_process_data(data):
    # Loại bỏ @Mention khỏi text
    data = (data.withColumn("free_text", f.regexp_replace(f.col("free_text"), user_regex, "")) 
    # Loại bỏ #Hashtag khỏi text
    .withColumn("free_text", f.regexp_replace(f.col("free_text"), hashtag_replace_regex, "$1"))
    # Loại bỏ URL khỏi text
    .withColumn("free_text", f.regexp_replace(f.col("free_text"), url_regex, "")) 
    # Loại bỏ Email khỏi text
    .withColumn("free_text", f.regexp_replace(f.col("free_text"), email_regex, ""))
    # Loại bỏ các khoảng trắng thừa trong câu
    .withColumn("free_text", f.regexp_replace(f.col("free_text"), " +", " "))
    # Loại vỏ các khoảng trắng đầu và cuối câu
    .withColumn("free_text", f.trim(f.col("free_text")))
    # Chuẩn hoá viết thường
    .withColumn("free_text", f.lower(f.col("free_text")))
    # Giữ lại các dòng mà đoạn text có nội dung
    .filter(f.col("free_text") != "")
    # Chuyển kiểu dữ liệu label_id thành kiểu int
    .withColumn('label_id', f.col('label_id').cast('int'))
    # Xóa dữ liệu có nhãn bị lỗi
    .where((f.col('label_id') == 0) | (f.col('label_id') == 1) | (f.col('label_id') == 2))
    # Tiền xử lý dữ liệu
    .withColumn('text', preprocess_udf('free_text'))
    # Encode text
    .withColumn('text_encoded', make_featues_text_udf('text'))
    # Encode label
    .withColumn('label_encoded', make_label_udf('label_id')))

    return data

# %%
df_train_clean = pre_process_data(df_train)
df_dev_clean = pre_process_data(df_dev)
df_test_clean = pre_process_data(df_test)

# %%
print(df_train_clean.count())
print(df_dev_clean.count())
print(df_test_clean.count())
# Out:
# 24043
# 2672
# 6680

# %% [markdown]
# ### **Step 4: Fit with Orca Estimator**
#
# First, create an Estimator.

# %%
from bigdl.orca.learn.tf2 import Estimator

batch_size = 256
est = Estimator.from_keras(model_creator=model_creator, workers_per_node=1)

# the path of the directory where to save the log files to be parsed by TensorBoard
tensorboard_dir = "runs"
# "bigdl" is the application name for tensorboard to save training and validation results under log path
est.set_tensorboard(tensorboard_dir, "bigdl")
# Out:
# 2022-07-01 05:41:33,448	INFO services.py:1340 -- View the Ray dashboard at http://172.28.0.2:8265
# {'node_ip_address': '172.28.0.2', 'raylet_ip_address': '172.28.0.2', 'redis_address': '172.28.0.2:6379', 'object_store_address': '/tmp/ray/session_2022-07-01_05-41-27_468288_61/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2022-07-01_05-41-27_468288_61/sockets/raylet', 'webui_url': '172.28.0.2:8265', 'session_dir': '/tmp/ray/session_2022-07-01_05-41-27_468288_61', 'metrics_export_port': 64132, 'node_id': '71dd1c99a885fe1b73d2582cef858cd66f37d48474e4617775451c59'}
# (Worker pid=1981) WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/bigdl/orca/learn/tf2/tf_runner.py:317: _CollectiveAllReduceStrategyExperimental.__init__ (from tensorflow.python.distribute.collective_all_reduce_strategy) is deprecated and will be removed in a future version.
# (Worker pid=1981) Instructions for updating:
# (Worker pid=1981) use distribute.MultiWorkerMirroredStrategy instead
# (Worker pid=1981) 2022-07-01 05:41:44.349029: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %% [markdown]
# Next, fit the Estimator.

# %%
stats = est.fit(
    data=df_train_clean,
    epochs=40,
    feature_cols=['text_encoded'],
    label_cols=['label_encoded'],
    batch_size=batch_size,
    steps_per_epoch=24043 // batch_size,
    validation_data=df_dev_clean,
    validation_steps=2672 // batch_size
)
# Out:
# (Worker pid=1981) WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/bigdl/orca/learn/tf2/tf_runner.py:195: StrategyBase.experimental_distribute_datasets_from_function (from tensorflow.python.distribute.distribute_lib) is deprecated and will be removed in a future version.
# (Worker pid=1981) Instructions for updating:
# (Worker pid=1981) rename to distribute_datasets_from_function
# (Worker pid=1981) 2022-07-01 05:43:59.623075: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# (Worker pid=1981) Epoch 1/40
#  1/93 [..............................] - ETA: 18:46 - loss: 1.0328 - accuracy: 0.7852
#  2/93 [..............................] - ETA: 6:28 - loss: 1.0390 - accuracy: 0.7832
#  3/93 [..............................] - ETA: 4:40 - loss: 1.0344 - accuracy: 0.7982
#  4/93 [>.............................] - ETA: 4:04 - loss: 1.0313 - accuracy: 0.8018
#  5/93 [>.............................] - ETA: 3:42 - loss: 1.0287 - accuracy: 0.8062
#  6/93 [>.............................] - ETA: 3:29 - loss: 1.0258 - accuracy: 0.8053
#  7/93 [=>............................] - ETA: 3:20 - loss: 1.0219 - accuracy: 0.8075
#  8/93 [=>............................] - ETA: 3:13 - loss: 1.0207 - accuracy: 0.8081
#  9/93 [=>............................] - ETA: 3:07 - loss: 1.0193 - accuracy: 0.8064
# 10/93 [==>...........................] - ETA: 3:01 - loss: 1.0181 - accuracy: 0.8051
# 11/93 [==>...........................] - ETA: 2:57 - loss: 1.0140 - accuracy: 0.8082
# 12/93 [==>...........................] - ETA: 2:53 - loss: 1.0116 - accuracy: 0.8089
# 13/93 [===>..........................] - ETA: 2:50 - loss: 1.0086 - accuracy: 0.8107
# 14/93 [===>..........................] - ETA: 2:47 - loss: 1.0044 - accuracy: 0.8145
# 15/93 [===>..........................] - ETA: 2:44 - loss: 1.0018 - accuracy: 0.8154
# 16/93 [====>.........................] - ETA: 2:40 - loss: 0.9987 - accuracy: 0.8171
# 17/93 [====>.........................] - ETA: 2:37 - loss: 0.9952 - accuracy: 0.8192
# 18/93 [====>.........................] - ETA: 2:35 - loss: 0.9932 - accuracy: 0.8188
# 19/93 [=====>........................] - ETA: 2:32 - loss: 0.9904 - accuracy: 0.8191
# 20/93 [=====>........................] - ETA: 2:30 - loss: 0.9887 - accuracy: 0.8172
# 21/93 [=====>........................] - ETA: 2:27 - loss: 0.9863 - accuracy: 0.8181
# 22/93 [======>.......................] - ETA: 2:24 - loss: 0.9832 - accuracy: 0.8203
# 23/93 [======>.......................] - ETA: 2:22 - loss: 0.9805 - accuracy: 0.8203
# 24/93 [======>.......................] - ETA: 2:19 - loss: 0.9778 - accuracy: 0.8201
# 25/93 [=======>......................] - ETA: 2:17 - loss: 0.9754 - accuracy: 0.8198
# 26/93 [=======>......................] - ETA: 2:15 - loss: 0.9731 - accuracy: 0.8197
# 27/93 [=======>......................] - ETA: 2:12 - loss: 0.9708 - accuracy: 0.8193
# 28/93 [========>.....................] - ETA: 2:10 - loss: 0.9688 - accuracy: 0.8189
# 29/93 [========>.....................] - ETA: 2:08 - loss: 0.9660 - accuracy: 0.8196
# 30/93 [========>.....................] - ETA: 2:06 - loss: 0.9641 - accuracy: 0.8188
# 31/93 [=========>....................] - ETA: 2:03 - loss: 0.9614 - accuracy: 0.8192
# 32/93 [=========>....................] - ETA: 2:01 - loss: 0.9590 - accuracy: 0.8193
# 33/93 [=========>....................] - ETA: 1:59 - loss: 0.9562 - accuracy: 0.8204
# 34/93 [=========>....................] - ETA: 1:57 - loss: 0.9537 - accuracy: 0.8209
# 35/93 [==========>...................] - ETA: 1:54 - loss: 0.9508 - accuracy: 0.8221
# 36/93 [==========>...................] - ETA: 1:52 - loss: 0.9482 - accuracy: 0.8218
# 37/93 [==========>...................] - ETA: 1:50 - loss: 0.9464 - accuracy: 0.8213
# 38/93 [===========>..................] - ETA: 1:48 - loss: 0.9448 - accuracy: 0.8200
# 39/93 [===========>..................] - ETA: 1:46 - loss: 0.9418 - accuracy: 0.8208
# 40/93 [===========>..................] - ETA: 1:43 - loss: 0.9394 - accuracy: 0.8212
# 41/93 [============>.................] - ETA: 1:41 - loss: 0.9367 - accuracy: 0.8217
# 42/93 [============>.................] - ETA: 1:39 - loss: 0.9351 - accuracy: 0.8212
# 43/93 [============>.................] - ETA: 1:37 - loss: 0.9328 - accuracy: 0.8210
# 44/93 [=============>................] - ETA: 1:35 - loss: 0.9306 - accuracy: 0.8208
# 45/93 [=============>................] - ETA: 1:33 - loss: 0.9284 - accuracy: 0.8207
# 46/93 [=============>................] - ETA: 1:31 - loss: 0.9270 - accuracy: 0.8198
# 47/93 [==============>...............] - ETA: 1:29 - loss: 0.9253 - accuracy: 0.8191
# 48/93 [==============>...............] - ETA: 1:27 - loss: 0.9236 - accuracy: 0.8184
# 49/93 [==============>...............] - ETA: 1:25 - loss: 0.9213 - accuracy: 0.8181
# 50/93 [===============>..............] - ETA: 1:23 - loss: 0.9188 - accuracy: 0.8183
# 51/93 [===============>..............] - ETA: 1:21 - loss: 0.9158 - accuracy: 0.8189
# 52/93 [===============>..............] - ETA: 1:19 - loss: 0.9130 - accuracy: 0.8193
# 53/93 [================>.............] - ETA: 1:17 - loss: 0.9108 - accuracy: 0.8188
# 54/93 [================>.............] - ETA: 1:15 - loss: 0.9083 - accuracy: 0.8190
# 55/93 [================>.............] - ETA: 1:13 - loss: 0.9049 - accuracy: 0.8203
# 56/93 [=================>............] - ETA: 1:11 - loss: 0.9027 - accuracy: 0.8200
# 57/93 [=================>............] - ETA: 1:09 - loss: 0.8994 - accuracy: 0.8209
# 58/93 [=================>............] - ETA: 1:07 - loss: 0.8967 - accuracy: 0.8213
# 59/93 [==================>...........] - ETA: 1:05 - loss: 0.8940 - accuracy: 0.8214
# 60/93 [==================>...........] - ETA: 1:03 - loss: 0.8918 - accuracy: 0.8214
# 61/93 [==================>...........] - ETA: 1:01 - loss: 0.8890 - accuracy: 0.8219
# 62/93 [===================>..........] - ETA: 1:00 - loss: 0.8862 - accuracy: 0.8225
# 63/93 [===================>..........] - ETA: 58s - loss: 0.8838 - accuracy: 0.8224
# 64/93 [===================>..........] - ETA: 56s - loss: 0.8808 - accuracy: 0.8230
# 65/93 [===================>..........] - ETA: 54s - loss: 0.8787 - accuracy: 0.8230
# 66/93 [====================>.........] - ETA: 52s - loss: 0.8762 - accuracy: 0.8231
# 67/93 [====================>.........] - ETA: 50s - loss: 0.8743 - accuracy: 0.8228
# 68/93 [====================>.........] - ETA: 48s - loss: 0.8715 - accuracy: 0.8230
# 69/93 [=====================>........] - ETA: 46s - loss: 0.8688 - accuracy: 0.8233
# 70/93 [=====================>........] - ETA: 44s - loss: 0.8664 - accuracy: 0.8234
# 71/93 [=====================>........] - ETA: 42s - loss: 0.8634 - accuracy: 0.8239
# 72/93 [======================>.......] - ETA: 40s - loss: 0.8606 - accuracy: 0.8242
# 73/93 [======================>.......] - ETA: 38s - loss: 0.8585 - accuracy: 0.8240
# 74/93 [======================>.......] - ETA: 36s - loss: 0.8565 - accuracy: 0.8240
# 75/93 [=======================>......] - ETA: 34s - loss: 0.8541 - accuracy: 0.8240
# 76/93 [=======================>......] - ETA: 32s - loss: 0.8517 - accuracy: 0.8240
# 77/93 [=======================>......] - ETA: 30s - loss: 0.8502 - accuracy: 0.8236
# 78/93 [========================>.....] - ETA: 28s - loss: 0.8470 - accuracy: 0.8241
# 79/93 [========================>.....] - ETA: 26s - loss: 0.8442 - accuracy: 0.8244
# 80/93 [========================>.....] - ETA: 25s - loss: 0.8421 - accuracy: 0.8243
# 81/93 [=========================>....] - ETA: 23s - loss: 0.8401 - accuracy: 0.8241
# 82/93 [=========================>....] - ETA: 21s - loss: 0.8377 - accuracy: 0.8241
# 83/93 [=========================>....] - ETA: 19s - loss: 0.8357 - accuracy: 0.8240
# 84/93 [==========================>...] - ETA: 17s - loss: 0.8339 - accuracy: 0.8236
# 85/93 [==========================>...] - ETA: 15s - loss: 0.8316 - accuracy: 0.8235
# 86/93 [==========================>...] - ETA: 13s - loss: 0.8296 - accuracy: 0.8235
# 87/93 [===========================>..] - ETA: 11s - loss: 0.8278 - accuracy: 0.8233
# 88/93 [===========================>..] - ETA: 9s - loss: 0.8248 - accuracy: 0.8239
# 89/93 [===========================>..] - ETA: 7s - loss: 0.8226 - accuracy: 0.8239
# 90/93 [============================>.] - ETA: 5s - loss: 0.8206 - accuracy: 0.8238
# 91/93 [============================>.] - ETA: 3s - loss: 0.8185 - accuracy: 0.8238
# 92/93 [============================>.] - ETA: 1s - loss: 0.8147 - accuracy: 0.8247
# 93/93 [==============================] - ETA: 0s - loss: 0.8125 - accuracy: 0.8248
# (Worker pid=1981) 2022-07-01 05:47:08.492242: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - 197s 2s/step - loss: 0.8125 - accuracy: 0.8248 - val_loss: 0.6236 - val_accuracy: 0.8211
# (Worker pid=1981) Epoch 2/40
#  1/93 [..............................] - ETA: 2:57 - loss: 0.6489 - accuracy: 0.8164
#  2/93 [..............................] - ETA: 2:48 - loss: 0.6127 - accuracy: 0.8301
#  3/93 [..............................] - ETA: 2:47 - loss: 0.6092 - accuracy: 0.8294
#  4/93 [>.............................] - ETA: 2:47 - loss: 0.6166 - accuracy: 0.8252
#  5/93 [>.............................] - ETA: 2:45 - loss: 0.6110 - accuracy: 0.8273
#  6/93 [>.............................] - ETA: 2:42 - loss: 0.6101 - accuracy: 0.8268
#  7/93 [=>............................] - ETA: 2:39 - loss: 0.6079 - accuracy: 0.8265
#  8/93 [=>............................] - ETA: 2:37 - loss: 0.6161 - accuracy: 0.8228
#  9/93 [=>............................] - ETA: 2:37 - loss: 0.6264 - accuracy: 0.8177
# 10/93 [==>...........................] - ETA: 2:35 - loss: 0.6184 - accuracy: 0.8203
# 11/93 [==>...........................] - ETA: 2:33 - loss: 0.6105 - accuracy: 0.8232
# 12/93 [==>...........................] - ETA: 2:32 - loss: 0.6043 - accuracy: 0.8255
# 13/93 [===>..........................] - ETA: 2:30 - loss: 0.5949 - accuracy: 0.8293
# 14/93 [===>..........................] - ETA: 2:28 - loss: 0.5896 - accuracy: 0.8315
# 15/93 [===>..........................] - ETA: 2:26 - loss: 0.5901 - accuracy: 0.8313
# 16/93 [====>.........................] - ETA: 2:24 - loss: 0.5904 - accuracy: 0.8308
# 17/93 [====>.........................] - ETA: 2:23 - loss: 0.5970 - accuracy: 0.8277
# 18/93 [====>.........................] - ETA: 2:21 - loss: 0.5901 - accuracy: 0.8303
# 19/93 [=====>........................] - ETA: 2:19 - loss: 0.5920 - accuracy: 0.8292
# 20/93 [=====>........................] - ETA: 2:17 - loss: 0.5986 - accuracy: 0.8264
# 21/93 [=====>........................] - ETA: 2:16 - loss: 0.5991 - accuracy: 0.8259
# 22/93 [======>.......................] - ETA: 2:14 - loss: 0.5975 - accuracy: 0.8265
# 23/93 [======>.......................] - ETA: 2:12 - loss: 0.5964 - accuracy: 0.8269
# 24/93 [======>.......................] - ETA: 2:12 - loss: 0.5947 - accuracy: 0.8273
# 25/93 [=======>......................] - ETA: 2:10 - loss: 0.5963 - accuracy: 0.8267
# 26/93 [=======>......................] - ETA: 2:08 - loss: 0.5980 - accuracy: 0.8260
# 27/93 [=======>......................] - ETA: 2:06 - loss: 0.6001 - accuracy: 0.8249
# 28/93 [========>.....................] - ETA: 2:04 - loss: 0.6047 - accuracy: 0.8227
# 29/93 [========>.....................] - ETA: 2:02 - loss: 0.6076 - accuracy: 0.8215
# 30/93 [========>.....................] - ETA: 2:00 - loss: 0.6066 - accuracy: 0.8216
# 31/93 [=========>....................] - ETA: 1:58 - loss: 0.6068 - accuracy: 0.8214
# 32/93 [=========>....................] - ETA: 1:56 - loss: 0.6022 - accuracy: 0.8235
# 33/93 [=========>....................] - ETA: 1:54 - loss: 0.6012 - accuracy: 0.8237
# 34/93 [=========>....................] - ETA: 1:52 - loss: 0.6004 - accuracy: 0.8240
# 35/93 [==========>...................] - ETA: 1:51 - loss: 0.6015 - accuracy: 0.8234
# 36/93 [==========>...................] - ETA: 1:49 - loss: 0.6000 - accuracy: 0.8240
# 37/93 [==========>...................] - ETA: 1:47 - loss: 0.5998 - accuracy: 0.8238
# 38/93 [===========>..................] - ETA: 1:45 - loss: 0.5995 - accuracy: 0.8239
# 39/93 [===========>..................] - ETA: 1:43 - loss: 0.5988 - accuracy: 0.8241
# 40/93 [===========>..................] - ETA: 1:41 - loss: 0.5961 - accuracy: 0.8253
# 41/93 [============>.................] - ETA: 1:39 - loss: 0.5945 - accuracy: 0.8259
# 42/93 [============>.................] - ETA: 1:37 - loss: 0.5950 - accuracy: 0.8255
# 43/93 [============>.................] - ETA: 1:35 - loss: 0.5965 - accuracy: 0.8247
# 44/93 [=============>................] - ETA: 1:33 - loss: 0.5957 - accuracy: 0.8248
# 45/93 [=============>................] - ETA: 1:31 - loss: 0.5960 - accuracy: 0.8247
# 46/93 [=============>................] - ETA: 1:29 - loss: 0.5944 - accuracy: 0.8253
# 47/93 [==============>...............] - ETA: 1:27 - loss: 0.5955 - accuracy: 0.8248
# 48/93 [==============>...............] - ETA: 1:25 - loss: 0.5959 - accuracy: 0.8245
# 49/93 [==============>...............] - ETA: 1:23 - loss: 0.5953 - accuracy: 0.8245
# 50/93 [===============>..............] - ETA: 1:21 - loss: 0.5968 - accuracy: 0.8238
# 51/93 [===============>..............] - ETA: 1:20 - loss: 0.5966 - accuracy: 0.8238
# 52/93 [===============>..............] - ETA: 1:19 - loss: 0.5967 - accuracy: 0.8236
# 53/93 [================>.............] - ETA: 1:18 - loss: 0.5973 - accuracy: 0.8233
# 54/93 [================>.............] - ETA: 1:16 - loss: 0.5976 - accuracy: 0.8231
# 55/93 [================>.............] - ETA: 1:14 - loss: 0.5976 - accuracy: 0.8230
# 56/93 [=================>............] - ETA: 1:12 - loss: 0.5977 - accuracy: 0.8228
# 57/93 [=================>............] - ETA: 1:10 - loss: 0.5962 - accuracy: 0.8234
# 58/93 [=================>............] - ETA: 1:08 - loss: 0.5966 - accuracy: 0.8231
# 59/93 [==================>...........] - ETA: 1:06 - loss: 0.5961 - accuracy: 0.8233
# 60/93 [==================>...........] - ETA: 1:04 - loss: 0.5957 - accuracy: 0.8233
# 61/93 [==================>...........] - ETA: 1:02 - loss: 0.5927 - accuracy: 0.8245
# 62/93 [===================>..........] - ETA: 1:00 - loss: 0.5918 - accuracy: 0.8249
# 63/93 [===================>..........] - ETA: 58s - loss: 0.5905 - accuracy: 0.8254
# 64/93 [===================>..........] - ETA: 56s - loss: 0.5925 - accuracy: 0.8244
# 65/93 [===================>..........] - ETA: 54s - loss: 0.5925 - accuracy: 0.8243
# 66/93 [====================>.........] - ETA: 52s - loss: 0.5916 - accuracy: 0.8246
# 67/93 [====================>.........] - ETA: 50s - loss: 0.5903 - accuracy: 0.8250
# 68/93 [====================>.........] - ETA: 48s - loss: 0.5908 - accuracy: 0.8246
# 69/93 [=====================>........] - ETA: 46s - loss: 0.5899 - accuracy: 0.8250
# 70/93 [=====================>........] - ETA: 44s - loss: 0.5906 - accuracy: 0.8246
# 71/93 [=====================>........] - ETA: 42s - loss: 0.5895 - accuracy: 0.8250
# 72/93 [======================>.......] - ETA: 40s - loss: 0.5892 - accuracy: 0.8250
# 73/93 [======================>.......] - ETA: 38s - loss: 0.5889 - accuracy: 0.8250
# 74/93 [======================>.......] - ETA: 36s - loss: 0.5876 - accuracy: 0.8255
# 75/93 [=======================>......] - ETA: 34s - loss: 0.5874 - accuracy: 0.8254
# 76/93 [=======================>......] - ETA: 33s - loss: 0.5871 - accuracy: 0.8255
# 77/93 [=======================>......] - ETA: 31s - loss: 0.5864 - accuracy: 0.8257
# 78/93 [========================>.....] - ETA: 29s - loss: 0.5859 - accuracy: 0.8259
# 79/93 [========================>.....] - ETA: 27s - loss: 0.5845 - accuracy: 0.8264
# 80/93 [========================>.....] - ETA: 25s - loss: 0.5846 - accuracy: 0.8263
# 81/93 [=========================>....] - ETA: 23s - loss: 0.5838 - accuracy: 0.8265
# 82/93 [=========================>....] - ETA: 21s - loss: 0.5837 - accuracy: 0.8264
# 83/93 [=========================>....] - ETA: 19s - loss: 0.5836 - accuracy: 0.8265
# 84/93 [==========================>...] - ETA: 17s - loss: 0.5829 - accuracy: 0.8267
# 85/93 [==========================>...] - ETA: 15s - loss: 0.5820 - accuracy: 0.8270
# 86/93 [==========================>...] - ETA: 13s - loss: 0.5806 - accuracy: 0.8275
# 87/93 [===========================>..] - ETA: 11s - loss: 0.5794 - accuracy: 0.8279
# 88/93 [===========================>..] - ETA: 9s - loss: 0.5788 - accuracy: 0.8282
# 89/93 [===========================>..] - ETA: 7s - loss: 0.5778 - accuracy: 0.8285
# 90/93 [============================>.] - ETA: 5s - loss: 0.5782 - accuracy: 0.8283
# 91/93 [============================>.] - ETA: 3s - loss: 0.5789 - accuracy: 0.8280
# 92/93 [============================>.] - ETA: 1s - loss: 0.5788 - accuracy: 0.8279
# 93/93 [==============================] - ETA: 0s - loss: 0.5788 - accuracy: 0.8277
# (Worker pid=1981) 2022-07-01 05:50:15.695942: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - 184s 2s/step - loss: 0.5788 - accuracy: 0.8277 - val_loss: 0.5814 - val_accuracy: 0.8211
# (Worker pid=1981) Epoch 3/40
#  1/93 [..............................] - ETA: 2:47 - loss: 0.6306 - accuracy: 0.7969
#  2/93 [..............................] - ETA: 2:49 - loss: 0.6051 - accuracy: 0.8105
#  3/93 [..............................] - ETA: 2:48 - loss: 0.5725 - accuracy: 0.8242
#  4/93 [>.............................] - ETA: 2:48 - loss: 0.5918 - accuracy: 0.8164
#  5/93 [>.............................] - ETA: 2:45 - loss: 0.5985 - accuracy: 0.8125
#  6/93 [>.............................] - ETA: 2:43 - loss: 0.5873 - accuracy: 0.8164
#  7/93 [=>............................] - ETA: 2:42 - loss: 0.5851 - accuracy: 0.8175
#  8/93 [=>............................] - ETA: 2:40 - loss: 0.5923 - accuracy: 0.8145
#  9/93 [=>............................] - ETA: 2:38 - loss: 0.5850 - accuracy: 0.8177
# 10/93 [==>...........................] - ETA: 2:35 - loss: 0.5803 - accuracy: 0.8195
# 11/93 [==>...........................] - ETA: 2:33 - loss: 0.5791 - accuracy: 0.8200
# 12/93 [==>...........................] - ETA: 2:31 - loss: 0.5789 - accuracy: 0.8197
# 13/93 [===>..........................] - ETA: 2:29 - loss: 0.5741 - accuracy: 0.8221
# 14/93 [===>..........................] - ETA: 2:27 - loss: 0.5696 - accuracy: 0.8239
# 15/93 [===>..........................] - ETA: 2:25 - loss: 0.5687 - accuracy: 0.8237
# 16/93 [====>.........................] - ETA: 2:23 - loss: 0.5674 - accuracy: 0.8245
# 17/93 [====>.........................] - ETA: 2:21 - loss: 0.5708 - accuracy: 0.8228
# 18/93 [====>.........................] - ETA: 2:19 - loss: 0.5704 - accuracy: 0.8229
# 19/93 [=====>........................] - ETA: 2:17 - loss: 0.5711 - accuracy: 0.8222
# 20/93 [=====>........................] - ETA: 2:15 - loss: 0.5679 - accuracy: 0.8232
# 21/93 [=====>........................] - ETA: 2:13 - loss: 0.5671 - accuracy: 0.8231
# 22/93 [======>.......................] - ETA: 2:11 - loss: 0.5682 - accuracy: 0.8224
# 23/93 [======>.......................] - ETA: 2:09 - loss: 0.5679 - accuracy: 0.8227
# 24/93 [======>.......................] - ETA: 2:07 - loss: 0.5687 - accuracy: 0.8221
# 25/93 [=======>......................] - ETA: 2:05 - loss: 0.5701 - accuracy: 0.8211
# 26/93 [=======>......................] - ETA: 2:04 - loss: 0.5713 - accuracy: 0.8206
# 27/93 [=======>......................] - ETA: 2:02 - loss: 0.5710 - accuracy: 0.8206
# 28/93 [========>.....................] - ETA: 2:00 - loss: 0.5742 - accuracy: 0.8192
# 29/93 [========>.....................] - ETA: 1:58 - loss: 0.5726 - accuracy: 0.8200
# 30/93 [========>.....................] - ETA: 1:56 - loss: 0.5743 - accuracy: 0.8190
# 31/93 [=========>....................] - ETA: 1:54 - loss: 0.5752 - accuracy: 0.8184
# 32/93 [=========>....................] - ETA: 1:52 - loss: 0.5753 - accuracy: 0.8182
# 33/93 [=========>....................] - ETA: 1:50 - loss: 0.5736 - accuracy: 0.8188
# 34/93 [=========>....................] - ETA: 1:49 - loss: 0.5717 - accuracy: 0.8196
# 35/93 [==========>...................] - ETA: 1:47 - loss: 0.5715 - accuracy: 0.8198
# 36/93 [==========>...................] - ETA: 1:45 - loss: 0.5692 - accuracy: 0.8206
# 37/93 [==========>...................] - ETA: 1:43 - loss: 0.5699 - accuracy: 0.8202
# 38/93 [===========>..................] - ETA: 1:41 - loss: 0.5707 - accuracy: 0.8198
# 39/93 [===========>..................] - ETA: 1:39 - loss: 0.5683 - accuracy: 0.8209
# 40/93 [===========>..................] - ETA: 1:38 - loss: 0.5691 - accuracy: 0.8205
# 41/93 [============>.................] - ETA: 1:36 - loss: 0.5683 - accuracy: 0.8208
# 42/93 [============>.................] - ETA: 1:34 - loss: 0.5691 - accuracy: 0.8204
# 43/93 [============>.................] - ETA: 1:32 - loss: 0.5686 - accuracy: 0.8204
# 44/93 [=============>................] - ETA: 1:30 - loss: 0.5689 - accuracy: 0.8202
# 45/93 [=============>................] - ETA: 1:29 - loss: 0.5665 - accuracy: 0.8213
# 46/93 [=============>................] - ETA: 1:27 - loss: 0.5663 - accuracy: 0.8212
# 47/93 [==============>...............] - ETA: 1:25 - loss: 0.5670 - accuracy: 0.8208
# 48/93 [==============>...............] - ETA: 1:23 - loss: 0.5666 - accuracy: 0.8210
# 49/93 [==============>...............] - ETA: 1:21 - loss: 0.5665 - accuracy: 0.8210
# 50/93 [===============>..............] - ETA: 1:19 - loss: 0.5658 - accuracy: 0.8213
# 51/93 [===============>..............] - ETA: 1:17 - loss: 0.5646 - accuracy: 0.8218
# 52/93 [===============>..............] - ETA: 1:16 - loss: 0.5642 - accuracy: 0.8218
# 53/93 [================>.............] - ETA: 1:14 - loss: 0.5631 - accuracy: 0.8224
# 54/93 [================>.............] - ETA: 1:12 - loss: 0.5633 - accuracy: 0.8223
# 55/93 [================>.............] - ETA: 1:10 - loss: 0.5624 - accuracy: 0.8227
# 56/93 [=================>............] - ETA: 1:08 - loss: 0.5632 - accuracy: 0.8223
# 57/93 [=================>............] - ETA: 1:06 - loss: 0.5632 - accuracy: 0.8222
# 58/93 [=================>............] - ETA: 1:04 - loss: 0.5618 - accuracy: 0.8227
# 59/93 [==================>...........] - ETA: 1:03 - loss: 0.5609 - accuracy: 0.8230
# 60/93 [==================>...........] - ETA: 1:01 - loss: 0.5596 - accuracy: 0.8235
# 61/93 [==================>...........] - ETA: 59s - loss: 0.5587 - accuracy: 0.8239
# 62/93 [===================>..........] - ETA: 57s - loss: 0.5594 - accuracy: 0.8235
# 63/93 [===================>..........] - ETA: 55s - loss: 0.5599 - accuracy: 0.8232
# 64/93 [===================>..........] - ETA: 53s - loss: 0.5589 - accuracy: 0.8237
# 65/93 [===================>..........] - ETA: 51s - loss: 0.5591 - accuracy: 0.8236
# 66/93 [====================>.........] - ETA: 50s - loss: 0.5601 - accuracy: 0.8229
# 67/93 [====================>.........] - ETA: 48s - loss: 0.5583 - accuracy: 0.8236
# 68/93 [====================>.........] - ETA: 46s - loss: 0.5577 - accuracy: 0.8238
# 69/93 [=====================>........] - ETA: 44s - loss: 0.5562 - accuracy: 0.8244
# 70/93 [=====================>........] - ETA: 42s - loss: 0.5564 - accuracy: 0.8242
# 71/93 [=====================>........] - ETA: 40s - loss: 0.5566 - accuracy: 0.8240
# 72/93 [======================>.......] - ETA: 38s - loss: 0.5556 - accuracy: 0.8243
# 73/93 [======================>.......] - ETA: 37s - loss: 0.5549 - accuracy: 0.8246
# 74/93 [======================>.......] - ETA: 35s - loss: 0.5543 - accuracy: 0.8247
# 75/93 [=======================>......] - ETA: 33s - loss: 0.5546 - accuracy: 0.8245
# 76/93 [=======================>......] - ETA: 31s - loss: 0.5541 - accuracy: 0.8247
# 77/93 [=======================>......] - ETA: 29s - loss: 0.5541 - accuracy: 0.8246
# 78/93 [========================>.....] - ETA: 27s - loss: 0.5548 - accuracy: 0.8243
# 79/93 [========================>.....] - ETA: 25s - loss: 0.5544 - accuracy: 0.8244
# 80/93 [========================>.....] - ETA: 24s - loss: 0.5536 - accuracy: 0.8247
# 81/93 [=========================>....] - ETA: 22s - loss: 0.5551 - accuracy: 0.8239
# 82/93 [=========================>....] - ETA: 20s - loss: 0.5544 - accuracy: 0.8242
# 83/93 [=========================>....] - ETA: 18s - loss: 0.5542 - accuracy: 0.8242
# 84/93 [==========================>...] - ETA: 16s - loss: 0.5532 - accuracy: 0.8246
# 85/93 [==========================>...] - ETA: 14s - loss: 0.5536 - accuracy: 0.8242
# 86/93 [==========================>...] - ETA: 12s - loss: 0.5526 - accuracy: 0.8246
# 87/93 [===========================>..] - ETA: 11s - loss: 0.5520 - accuracy: 0.8248
# 88/93 [===========================>..] - ETA: 9s - loss: 0.5517 - accuracy: 0.8249
# 89/93 [===========================>..] - ETA: 7s - loss: 0.5510 - accuracy: 0.8252
# 90/93 [============================>.] - ETA: 5s - loss: 0.5509 - accuracy: 0.8251
# 91/93 [============================>.] - ETA: 3s - loss: 0.5505 - accuracy: 0.8253
# 92/93 [============================>.] - ETA: 1s - loss: 0.5502 - accuracy: 0.8255
# 93/93 [==============================] - ETA: 0s - loss: 0.5502 - accuracy: 0.8254
# (Worker pid=1981) 2022-07-01 05:53:13.175776: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - 177s 2s/step - loss: 0.5502 - accuracy: 0.8254 - val_loss: 0.5513 - val_accuracy: 0.8207
# (Worker pid=1981) Epoch 4/40
#  1/93 [..............................] - ETA: 2:53 - loss: 0.4817 - accuracy: 0.8477
#  2/93 [..............................] - ETA: 2:45 - loss: 0.4598 - accuracy: 0.8594
#  3/93 [..............................] - ETA: 2:44 - loss: 0.4882 - accuracy: 0.8464
#  4/93 [>.............................] - ETA: 2:43 - loss: 0.5080 - accuracy: 0.8369
#  5/93 [>.............................] - ETA: 2:42 - loss: 0.5307 - accuracy: 0.8281
#  6/93 [>.............................] - ETA: 2:40 - loss: 0.5434 - accuracy: 0.8216
#  7/93 [=>............................] - ETA: 2:38 - loss: 0.5420 - accuracy: 0.8225
#  8/93 [=>............................] - ETA: 2:36 - loss: 0.5312 - accuracy: 0.8271
#  9/93 [=>............................] - ETA: 2:35 - loss: 0.5232 - accuracy: 0.8303
# 10/93 [==>...........................] - ETA: 2:33 - loss: 0.5247 - accuracy: 0.8297
# 11/93 [==>...........................] - ETA: 2:31 - loss: 0.5254 - accuracy: 0.8292
# 12/93 [==>...........................] - ETA: 2:29 - loss: 0.5287 - accuracy: 0.8275
# 13/93 [===>..........................] - ETA: 2:32 - loss: 0.5301 - accuracy: 0.8260
# 14/93 [===>..........................] - ETA: 2:46 - loss: 0.5337 - accuracy: 0.8242
# 15/93 [===>..........................] - ETA: 2:43 - loss: 0.5312 - accuracy: 0.8255
# 16/93 [====>.........................] - ETA: 2:40 - loss: 0.5323 - accuracy: 0.8245
# 17/93 [====>.........................] - ETA: 2:37 - loss: 0.5327 - accuracy: 0.8238
# 18/93 [====>.........................] - ETA: 2:35 - loss: 0.5290 - accuracy: 0.8253
# 19/93 [=====>........................] - ETA: 2:32 - loss: 0.5283 - accuracy: 0.8259
# 20/93 [=====>........................] - ETA: 2:29 - loss: 0.5258 - accuracy: 0.8266
# 21/93 [=====>........................] - ETA: 2:26 - loss: 0.5271 - accuracy: 0.8257
# 22/93 [======>.......................] - ETA: 2:24 - loss: 0.5274 - accuracy: 0.8256
# 23/93 [======>.......................] - ETA: 2:21 - loss: 0.5282 - accuracy: 0.8251
# 24/93 [======>.......................] - ETA: 2:19 - loss: 0.5274 - accuracy: 0.8254
# 25/93 [=======>......................] - ETA: 2:16 - loss: 0.5266 - accuracy: 0.8256
# 26/93 [=======>......................] - ETA: 2:14 - loss: 0.5255 - accuracy: 0.8262
# 27/93 [=======>......................] - ETA: 2:12 - loss: 0.5235 - accuracy: 0.8271
# 28/93 [========>.....................] - ETA: 2:09 - loss: 0.5232 - accuracy: 0.8273
# 29/93 [========>.....................] - ETA: 2:07 - loss: 0.5215 - accuracy: 0.8280
# 30/93 [========>.....................] - ETA: 2:05 - loss: 0.5198 - accuracy: 0.8289
# 31/93 [=========>....................] - ETA: 2:06 - loss: 0.5218 - accuracy: 0.8277
# 32/93 [=========>....................] - ETA: 2:06 - loss: 0.5212 - accuracy: 0.8281
# 33/93 [=========>....................] - ETA: 2:06 - loss: 0.5241 - accuracy: 0.8268
# 34/93 [=========>....................] - ETA: 2:07 - loss: 0.5239 - accuracy: 0.8267
# 35/93 [==========>...................] - ETA: 2:06 - loss: 0.5245 - accuracy: 0.8268
# 36/93 [==========>...................] - ETA: 2:06 - loss: 0.5238 - accuracy: 0.8269
# 37/93 [==========>...................] - ETA: 2:06 - loss: 0.5228 - accuracy: 0.8273
# 38/93 [===========>..................] - ETA: 2:04 - loss: 0.5220 - accuracy: 0.8276
# 39/93 [===========>..................] - ETA: 2:01 - loss: 0.5209 - accuracy: 0.8279
# 40/93 [===========>..................] - ETA: 1:59 - loss: 0.5206 - accuracy: 0.8279
# 41/93 [============>.................] - ETA: 1:56 - loss: 0.5219 - accuracy: 0.8273
# 42/93 [============>.................] - ETA: 1:53 - loss: 0.5227 - accuracy: 0.8267
# 43/93 [============>.................] - ETA: 1:51 - loss: 0.5227 - accuracy: 0.8268
# 44/93 [=============>................] - ETA: 1:48 - loss: 0.5225 - accuracy: 0.8269
# 45/93 [=============>................] - ETA: 1:45 - loss: 0.5204 - accuracy: 0.8278
# 46/93 [=============>................] - ETA: 1:43 - loss: 0.5206 - accuracy: 0.8274
# 47/93 [==============>...............] - ETA: 1:42 - loss: 0.5206 - accuracy: 0.8275
# 48/93 [==============>...............] - ETA: 1:41 - loss: 0.5219 - accuracy: 0.8266
# 49/93 [==============>...............] - ETA: 1:39 - loss: 0.5224 - accuracy: 0.8262
# 50/93 [===============>..............] - ETA: 1:36 - loss: 0.5230 - accuracy: 0.8258
# 51/93 [===============>..............] - ETA: 1:34 - loss: 0.5229 - accuracy: 0.8256
# 52/93 [===============>..............] - ETA: 1:31 - loss: 0.5226 - accuracy: 0.8257
# 53/93 [================>.............] - ETA: 1:28 - loss: 0.5220 - accuracy: 0.8258
# 54/93 [================>.............] - ETA: 1:26 - loss: 0.5221 - accuracy: 0.8254
# 55/93 [================>.............] - ETA: 1:23 - loss: 0.5210 - accuracy: 0.8260
# 56/93 [=================>............] - ETA: 1:21 - loss: 0.5214 - accuracy: 0.8257
# 57/93 [=================>............] - ETA: 1:19 - loss: 0.5216 - accuracy: 0.8256
# 58/93 [=================>............] - ETA: 1:16 - loss: 0.5215 - accuracy: 0.8256
# 59/93 [==================>...........] - ETA: 1:14 - loss: 0.5210 - accuracy: 0.8259
# 60/93 [==================>...........] - ETA: 1:11 - loss: 0.5211 - accuracy: 0.8257
# 61/93 [==================>...........] - ETA: 1:09 - loss: 0.5218 - accuracy: 0.8253
# 62/93 [===================>..........] - ETA: 1:07 - loss: 0.5220 - accuracy: 0.8252
# 63/93 [===================>..........] - ETA: 1:05 - loss: 0.5216 - accuracy: 0.8253
# 64/93 [===================>..........] - ETA: 1:02 - loss: 0.5209 - accuracy: 0.8257
# 65/93 [===================>..........] - ETA: 1:00 - loss: 0.5197 - accuracy: 0.8261
# 66/93 [====================>.........] - ETA: 58s - loss: 0.5185 - accuracy: 0.8266
# 67/93 [====================>.........] - ETA: 56s - loss: 0.5193 - accuracy: 0.8263
# 68/93 [====================>.........] - ETA: 54s - loss: 0.5185 - accuracy: 0.8266
# 69/93 [=====================>........] - ETA: 52s - loss: 0.5183 - accuracy: 0.8267
# 70/93 [=====================>........] - ETA: 50s - loss: 0.5184 - accuracy: 0.8264
# 71/93 [=====================>........] - ETA: 48s - loss: 0.5181 - accuracy: 0.8264
# 72/93 [======================>.......] - ETA: 46s - loss: 0.5171 - accuracy: 0.8267
# 73/93 [======================>.......] - ETA: 44s - loss: 0.5155 - accuracy: 0.8273
# 74/93 [======================>.......] - ETA: 42s - loss: 0.5157 - accuracy: 0.8271
# 75/93 [=======================>......] - ETA: 40s - loss: 0.5163 - accuracy: 0.8268
# 76/93 [=======================>......] - ETA: 38s - loss: 0.5151 - accuracy: 0.8273
# 77/93 [=======================>......] - ETA: 36s - loss: 0.5144 - accuracy: 0.8276
# 78/93 [========================>.....] - ETA: 34s - loss: 0.5143 - accuracy: 0.8276
# 79/93 [========================>.....] - ETA: 32s - loss: 0.5157 - accuracy: 0.8270
# 80/93 [========================>.....] - ETA: 29s - loss: 0.5156 - accuracy: 0.8271
# 81/93 [=========================>....] - ETA: 27s - loss: 0.5154 - accuracy: 0.8271
# 82/93 [=========================>....] - ETA: 25s - loss: 0.5147 - accuracy: 0.8273
# 83/93 [=========================>....] - ETA: 22s - loss: 0.5142 - accuracy: 0.8275
# 84/93 [==========================>...] - ETA: 20s - loss: 0.5132 - accuracy: 0.8279
# 85/93 [==========================>...] - ETA: 18s - loss: 0.5135 - accuracy: 0.8276
# 86/93 [==========================>...] - ETA: 15s - loss: 0.5128 - accuracy: 0.8279
# 87/93 [===========================>..] - ETA: 13s - loss: 0.5121 - accuracy: 0.8282
# 88/93 [===========================>..] - ETA: 11s - loss: 0.5113 - accuracy: 0.8285
# 89/93 [===========================>..] - ETA: 9s - loss: 0.5105 - accuracy: 0.8289
# 90/93 [============================>.] - ETA: 6s - loss: 0.5102 - accuracy: 0.8289
# 91/93 [============================>.] - ETA: 4s - loss: 0.5108 - accuracy: 0.8286
# 92/93 [============================>.] - ETA: 2s - loss: 0.5104 - accuracy: 0.8287
# (Worker pid=1981) 2022-07-01 05:56:49.278401: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - ETA: 0s - loss: 0.5098 - accuracy: 0.8289
# 93/93 [==============================] - 216s 2s/step - loss: 0.5098 - accuracy: 0.8289 - val_loss: 0.5144 - val_accuracy: 0.8215
# (Worker pid=1981) Epoch 5/40
#  1/93 [..............................] - ETA: 2:51 - loss: 0.5360 - accuracy: 0.8086
#  2/93 [..............................] - ETA: 2:47 - loss: 0.5122 - accuracy: 0.8223
#  3/93 [..............................] - ETA: 2:48 - loss: 0.4908 - accuracy: 0.8333
#  4/93 [>.............................] - ETA: 2:46 - loss: 0.5077 - accuracy: 0.8262
#  5/93 [>.............................] - ETA: 2:45 - loss: 0.5076 - accuracy: 0.8234
#  6/93 [>.............................] - ETA: 2:43 - loss: 0.5193 - accuracy: 0.8158
#  7/93 [=>............................] - ETA: 2:40 - loss: 0.5082 - accuracy: 0.8198
#  8/93 [=>............................] - ETA: 2:39 - loss: 0.4984 - accuracy: 0.8252
#  9/93 [=>............................] - ETA: 2:36 - loss: 0.5090 - accuracy: 0.8203
# 10/93 [==>...........................] - ETA: 2:34 - loss: 0.5049 - accuracy: 0.8223
# 11/93 [==>...........................] - ETA: 2:33 - loss: 0.4964 - accuracy: 0.8256
# 12/93 [==>...........................] - ETA: 2:31 - loss: 0.4966 - accuracy: 0.8255
# 13/93 [===>..........................] - ETA: 2:29 - loss: 0.4954 - accuracy: 0.8263
# 14/93 [===>..........................] - ETA: 2:27 - loss: 0.4979 - accuracy: 0.8259
# 15/93 [===>..........................] - ETA: 2:26 - loss: 0.4995 - accuracy: 0.8242
# 16/93 [====>.........................] - ETA: 2:24 - loss: 0.4960 - accuracy: 0.8257
# 17/93 [====>.........................] - ETA: 2:22 - loss: 0.4975 - accuracy: 0.8244
# 18/93 [====>.........................] - ETA: 2:20 - loss: 0.4931 - accuracy: 0.8262
# 19/93 [=====>........................] - ETA: 2:19 - loss: 0.4953 - accuracy: 0.8252
# 20/93 [=====>........................] - ETA: 2:17 - loss: 0.4951 - accuracy: 0.8256
# 21/93 [=====>........................] - ETA: 2:15 - loss: 0.4940 - accuracy: 0.8266
# 22/93 [======>.......................] - ETA: 2:13 - loss: 0.4937 - accuracy: 0.8269
# 23/93 [======>.......................] - ETA: 2:11 - loss: 0.4936 - accuracy: 0.8266
# 24/93 [======>.......................] - ETA: 2:09 - loss: 0.4938 - accuracy: 0.8265
# 25/93 [=======>......................] - ETA: 2:07 - loss: 0.4913 - accuracy: 0.8273
# 26/93 [=======>......................] - ETA: 2:05 - loss: 0.4896 - accuracy: 0.8278
# 27/93 [=======>......................] - ETA: 2:11 - loss: 0.4888 - accuracy: 0.8284
# 28/93 [========>.....................] - ETA: 2:11 - loss: 0.4907 - accuracy: 0.8276
# 29/93 [========>.....................] - ETA: 2:09 - loss: 0.4917 - accuracy: 0.8269
# 30/93 [========>.....................] - ETA: 2:06 - loss: 0.4913 - accuracy: 0.8267
# 31/93 [=========>....................] - ETA: 2:04 - loss: 0.4902 - accuracy: 0.8270
# 32/93 [=========>....................] - ETA: 2:02 - loss: 0.4904 - accuracy: 0.8270
# 33/93 [=========>....................] - ETA: 2:00 - loss: 0.4872 - accuracy: 0.8286
# 34/93 [=========>....................] - ETA: 1:57 - loss: 0.4871 - accuracy: 0.8289
# 35/93 [==========>...................] - ETA: 1:55 - loss: 0.4864 - accuracy: 0.8291
# 36/93 [==========>...................] - ETA: 1:53 - loss: 0.4860 - accuracy: 0.8290
# 37/93 [==========>...................] - ETA: 1:51 - loss: 0.4866 - accuracy: 0.8282
# 38/93 [===========>..................] - ETA: 1:49 - loss: 0.4863 - accuracy: 0.8284
# 39/93 [===========>..................] - ETA: 1:47 - loss: 0.4854 - accuracy: 0.8287
# 40/93 [===========>..................] - ETA: 1:44 - loss: 0.4854 - accuracy: 0.8288
# 41/93 [============>.................] - ETA: 1:42 - loss: 0.4839 - accuracy: 0.8296
# 42/93 [============>.................] - ETA: 1:40 - loss: 0.4860 - accuracy: 0.8284
# 43/93 [============>.................] - ETA: 1:38 - loss: 0.4859 - accuracy: 0.8284
# 44/93 [=============>................] - ETA: 1:36 - loss: 0.4845 - accuracy: 0.8294
# 45/93 [=============>................] - ETA: 1:34 - loss: 0.4848 - accuracy: 0.8291
# 46/93 [=============>................] - ETA: 1:32 - loss: 0.4834 - accuracy: 0.8298
# 47/93 [==============>...............] - ETA: 1:30 - loss: 0.4823 - accuracy: 0.8303
# 48/93 [==============>...............] - ETA: 1:28 - loss: 0.4815 - accuracy: 0.8306
# 49/93 [==============>...............] - ETA: 1:27 - loss: 0.4805 - accuracy: 0.8310
# 50/93 [===============>..............] - ETA: 1:26 - loss: 0.4812 - accuracy: 0.8309
# 51/93 [===============>..............] - ETA: 1:24 - loss: 0.4804 - accuracy: 0.8313
# 52/93 [===============>..............] - ETA: 1:22 - loss: 0.4803 - accuracy: 0.8314
# 53/93 [================>.............] - ETA: 1:20 - loss: 0.4803 - accuracy: 0.8311
# 54/93 [================>.............] - ETA: 1:18 - loss: 0.4797 - accuracy: 0.8312
# 55/93 [================>.............] - ETA: 1:16 - loss: 0.4808 - accuracy: 0.8306
# 56/93 [=================>............] - ETA: 1:13 - loss: 0.4805 - accuracy: 0.8310
# 57/93 [=================>............] - ETA: 1:11 - loss: 0.4800 - accuracy: 0.8311
# 58/93 [=================>............] - ETA: 1:09 - loss: 0.4790 - accuracy: 0.8314
# 59/93 [==================>...........] - ETA: 1:07 - loss: 0.4792 - accuracy: 0.8313
# 60/93 [==================>...........] - ETA: 1:05 - loss: 0.4793 - accuracy: 0.8313
# 61/93 [==================>...........] - ETA: 1:03 - loss: 0.4788 - accuracy: 0.8316
# 62/93 [===================>..........] - ETA: 1:01 - loss: 0.4772 - accuracy: 0.8324
# 63/93 [===================>..........] - ETA: 59s - loss: 0.4779 - accuracy: 0.8321
# 64/93 [===================>..........] - ETA: 57s - loss: 0.4778 - accuracy: 0.8320
# 65/93 [===================>..........] - ETA: 55s - loss: 0.4767 - accuracy: 0.8326
# 66/93 [====================>.........] - ETA: 53s - loss: 0.4749 - accuracy: 0.8336
# 67/93 [====================>.........] - ETA: 51s - loss: 0.4746 - accuracy: 0.8337
# 68/93 [====================>.........] - ETA: 49s - loss: 0.4728 - accuracy: 0.8343
# 69/93 [=====================>........] - ETA: 47s - loss: 0.4728 - accuracy: 0.8343
# 70/93 [=====================>........] - ETA: 45s - loss: 0.4713 - accuracy: 0.8350
# 71/93 [=====================>........] - ETA: 43s - loss: 0.4727 - accuracy: 0.8344
# 72/93 [======================>.......] - ETA: 41s - loss: 0.4722 - accuracy: 0.8346
# 73/93 [======================>.......] - ETA: 39s - loss: 0.4710 - accuracy: 0.8351
# 74/93 [======================>.......] - ETA: 37s - loss: 0.4701 - accuracy: 0.8355
# 75/93 [=======================>......] - ETA: 35s - loss: 0.4697 - accuracy: 0.8357
# 76/93 [=======================>......] - ETA: 33s - loss: 0.4703 - accuracy: 0.8354
# 77/93 [=======================>......] - ETA: 31s - loss: 0.4701 - accuracy: 0.8354
# 78/93 [========================>.....] - ETA: 29s - loss: 0.4701 - accuracy: 0.8354
# 79/93 [========================>.....] - ETA: 27s - loss: 0.4698 - accuracy: 0.8353
# 80/93 [========================>.....] - ETA: 25s - loss: 0.4693 - accuracy: 0.8355
# 81/93 [=========================>....] - ETA: 23s - loss: 0.4689 - accuracy: 0.8358
# 82/93 [=========================>....] - ETA: 21s - loss: 0.4686 - accuracy: 0.8358
# 83/93 [=========================>....] - ETA: 19s - loss: 0.4686 - accuracy: 0.8357
# 84/93 [==========================>...] - ETA: 17s - loss: 0.4683 - accuracy: 0.8358
# 85/93 [==========================>...] - ETA: 15s - loss: 0.4680 - accuracy: 0.8359
# 86/93 [==========================>...] - ETA: 13s - loss: 0.4681 - accuracy: 0.8360
# 87/93 [===========================>..] - ETA: 11s - loss: 0.4682 - accuracy: 0.8361
# 88/93 [===========================>..] - ETA: 9s - loss: 0.4680 - accuracy: 0.8362
# 89/93 [===========================>..] - ETA: 7s - loss: 0.4674 - accuracy: 0.8364
# 90/93 [============================>.] - ETA: 5s - loss: 0.4673 - accuracy: 0.8363
# 91/93 [============================>.] - ETA: 3s - loss: 0.4676 - accuracy: 0.8360
# 92/93 [============================>.] - ETA: 1s - loss: 0.4680 - accuracy: 0.8360
# 93/93 [==============================] - ETA: 0s - loss: 0.4670 - accuracy: 0.8364
# (Worker pid=1981) 2022-07-01 05:59:57.249601: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - 188s 2s/step - loss: 0.4670 - accuracy: 0.8364 - val_loss: 0.4685 - val_accuracy: 0.8387
# (Worker pid=1981) Epoch 6/40
#  1/93 [..............................] - ETA: 2:46 - loss: 0.4626 - accuracy: 0.8398
#  2/93 [..............................] - ETA: 2:54 - loss: 0.4333 - accuracy: 0.8535
#  3/93 [..............................] - ETA: 2:49 - loss: 0.4317 - accuracy: 0.8503
#  4/93 [>.............................] - ETA: 2:49 - loss: 0.4569 - accuracy: 0.8398
#  5/93 [>.............................] - ETA: 2:47 - loss: 0.4610 - accuracy: 0.8367
#  6/93 [>.............................] - ETA: 2:45 - loss: 0.4388 - accuracy: 0.8483
#  7/93 [=>............................] - ETA: 2:43 - loss: 0.4426 - accuracy: 0.8477
#  8/93 [=>............................] - ETA: 2:41 - loss: 0.4478 - accuracy: 0.8447
#  9/93 [=>............................] - ETA: 2:40 - loss: 0.4384 - accuracy: 0.8498
# 10/93 [==>...........................] - ETA: 2:38 - loss: 0.4312 - accuracy: 0.8512
# 11/93 [==>...........................] - ETA: 2:36 - loss: 0.4328 - accuracy: 0.8509
# 12/93 [==>...........................] - ETA: 2:34 - loss: 0.4289 - accuracy: 0.8532
# 13/93 [===>..........................] - ETA: 2:32 - loss: 0.4305 - accuracy: 0.8522
# 14/93 [===>..........................] - ETA: 2:30 - loss: 0.4265 - accuracy: 0.8530
# 15/93 [===>..........................] - ETA: 2:28 - loss: 0.4265 - accuracy: 0.8526
# 16/93 [====>.........................] - ETA: 2:26 - loss: 0.4343 - accuracy: 0.8489
# 17/93 [====>.........................] - ETA: 2:24 - loss: 0.4365 - accuracy: 0.8479
# 18/93 [====>.........................] - ETA: 2:22 - loss: 0.4374 - accuracy: 0.8472
# 19/93 [=====>........................] - ETA: 2:21 - loss: 0.4364 - accuracy: 0.8475
# 20/93 [=====>........................] - ETA: 2:19 - loss: 0.4371 - accuracy: 0.8477
# 21/93 [=====>........................] - ETA: 2:16 - loss: 0.4358 - accuracy: 0.8484
# 22/93 [======>.......................] - ETA: 2:15 - loss: 0.4336 - accuracy: 0.8493
# 23/93 [======>.......................] - ETA: 2:13 - loss: 0.4348 - accuracy: 0.8482
# 24/93 [======>.......................] - ETA: 2:11 - loss: 0.4347 - accuracy: 0.8481
# 25/93 [=======>......................] - ETA: 2:09 - loss: 0.4337 - accuracy: 0.8486
# 26/93 [=======>......................] - ETA: 2:07 - loss: 0.4340 - accuracy: 0.8486
# 27/93 [=======>......................] - ETA: 2:05 - loss: 0.4340 - accuracy: 0.8485
# 28/93 [========>.....................] - ETA: 2:03 - loss: 0.4344 - accuracy: 0.8481
# 29/93 [========>.....................] - ETA: 2:01 - loss: 0.4337 - accuracy: 0.8479
# 30/93 [========>.....................] - ETA: 1:59 - loss: 0.4332 - accuracy: 0.8483
# 31/93 [=========>....................] - ETA: 1:58 - loss: 0.4337 - accuracy: 0.8478
# 32/93 [=========>....................] - ETA: 1:56 - loss: 0.4326 - accuracy: 0.8483
# 33/93 [=========>....................] - ETA: 1:54 - loss: 0.4313 - accuracy: 0.8492
# 34/93 [=========>....................] - ETA: 1:52 - loss: 0.4325 - accuracy: 0.8489
# 35/93 [==========>...................] - ETA: 1:50 - loss: 0.4318 - accuracy: 0.8489
# 36/93 [==========>...................] - ETA: 1:48 - loss: 0.4326 - accuracy: 0.8490
# 37/93 [==========>...................] - ETA: 1:46 - loss: 0.4304 - accuracy: 0.8500
# 38/93 [===========>..................] - ETA: 1:44 - loss: 0.4299 - accuracy: 0.8503
# 39/93 [===========>..................] - ETA: 1:42 - loss: 0.4292 - accuracy: 0.8507
# 40/93 [===========>..................] - ETA: 1:41 - loss: 0.4296 - accuracy: 0.8506
# 41/93 [============>.................] - ETA: 1:39 - loss: 0.4298 - accuracy: 0.8505
# 42/93 [============>.................] - ETA: 1:38 - loss: 0.4291 - accuracy: 0.8506
# 43/93 [============>.................] - ETA: 1:36 - loss: 0.4284 - accuracy: 0.8509
# 44/93 [=============>................] - ETA: 1:34 - loss: 0.4297 - accuracy: 0.8505
# 45/93 [=============>................] - ETA: 1:32 - loss: 0.4294 - accuracy: 0.8503
# 46/93 [=============>................] - ETA: 1:30 - loss: 0.4281 - accuracy: 0.8509
# 47/93 [==============>...............] - ETA: 1:28 - loss: 0.4288 - accuracy: 0.8505
# 48/93 [==============>...............] - ETA: 1:26 - loss: 0.4290 - accuracy: 0.8503
# 49/93 [==============>...............] - ETA: 1:24 - loss: 0.4281 - accuracy: 0.8507
# 50/93 [===============>..............] - ETA: 1:22 - loss: 0.4283 - accuracy: 0.8508
# 51/93 [===============>..............] - ETA: 1:20 - loss: 0.4278 - accuracy: 0.8509
# 52/93 [===============>..............] - ETA: 1:18 - loss: 0.4277 - accuracy: 0.8507
# 53/93 [================>.............] - ETA: 1:16 - loss: 0.4279 - accuracy: 0.8504
# 54/93 [================>.............] - ETA: 1:14 - loss: 0.4272 - accuracy: 0.8505
# 55/93 [================>.............] - ETA: 1:13 - loss: 0.4282 - accuracy: 0.8497
# 56/93 [=================>............] - ETA: 1:11 - loss: 0.4287 - accuracy: 0.8494
# 57/93 [=================>............] - ETA: 1:09 - loss: 0.4285 - accuracy: 0.8499
# 58/93 [=================>............] - ETA: 1:07 - loss: 0.4290 - accuracy: 0.8495
# 59/93 [==================>...........] - ETA: 1:05 - loss: 0.4288 - accuracy: 0.8494
# 60/93 [==================>...........] - ETA: 1:03 - loss: 0.4298 - accuracy: 0.8491
# 61/93 [==================>...........] - ETA: 1:01 - loss: 0.4290 - accuracy: 0.8491
# 62/93 [===================>..........] - ETA: 59s - loss: 0.4288 - accuracy: 0.8492
# 63/93 [===================>..........] - ETA: 57s - loss: 0.4274 - accuracy: 0.8499
# 64/93 [===================>..........] - ETA: 55s - loss: 0.4280 - accuracy: 0.8495
# 65/93 [===================>..........] - ETA: 53s - loss: 0.4272 - accuracy: 0.8497
# 66/93 [====================>.........] - ETA: 51s - loss: 0.4268 - accuracy: 0.8497
# 67/93 [====================>.........] - ETA: 49s - loss: 0.4266 - accuracy: 0.8497
# 68/93 [====================>.........] - ETA: 47s - loss: 0.4262 - accuracy: 0.8499
# 69/93 [=====================>........] - ETA: 46s - loss: 0.4254 - accuracy: 0.8503
# ...
#  8/93 [=>............................] - ETA: 2:42 - loss: 0.1071 - accuracy: 0.9614
#  9/93 [=>............................] - ETA: 2:40 - loss: 0.1074 - accuracy: 0.9614
# 10/93 [==>...........................] - ETA: 2:38 - loss: 0.1093 - accuracy: 0.9602
# 11/93 [==>...........................] - ETA: 2:35 - loss: 0.1165 - accuracy: 0.9592
# 12/93 [==>...........................] - ETA: 2:33 - loss: 0.1157 - accuracy: 0.9593
# 13/93 [===>..........................] - ETA: 2:31 - loss: 0.1136 - accuracy: 0.9603
# 14/93 [===>..........................] - ETA: 2:28 - loss: 0.1155 - accuracy: 0.9601
# 15/93 [===>..........................] - ETA: 2:26 - loss: 0.1163 - accuracy: 0.9602
# 16/93 [====>.........................] - ETA: 2:23 - loss: 0.1169 - accuracy: 0.9600
# 17/93 [====>.........................] - ETA: 2:21 - loss: 0.1173 - accuracy: 0.9600
# 18/93 [====>.........................] - ETA: 2:20 - loss: 0.1148 - accuracy: 0.9607
# 19/93 [=====>........................] - ETA: 2:18 - loss: 0.1126 - accuracy: 0.9620
# 20/93 [=====>........................] - ETA: 2:16 - loss: 0.1124 - accuracy: 0.9621
# 21/93 [=====>........................] - ETA: 2:14 - loss: 0.1126 - accuracy: 0.9624
# 22/93 [======>.......................] - ETA: 2:12 - loss: 0.1149 - accuracy: 0.9620
# 23/93 [======>.......................] - ETA: 2:11 - loss: 0.1165 - accuracy: 0.9613
# 24/93 [======>.......................] - ETA: 2:09 - loss: 0.1158 - accuracy: 0.9618
# 25/93 [=======>......................] - ETA: 2:07 - loss: 0.1153 - accuracy: 0.9623
# 26/93 [=======>......................] - ETA: 2:05 - loss: 0.1141 - accuracy: 0.9627
# 27/93 [=======>......................] - ETA: 2:03 - loss: 0.1130 - accuracy: 0.9631
# 28/93 [========>.....................] - ETA: 2:02 - loss: 0.1118 - accuracy: 0.9634
# 29/93 [========>.....................] - ETA: 2:04 - loss: 0.1117 - accuracy: 0.9635
# 30/93 [========>.....................] - ETA: 2:04 - loss: 0.1107 - accuracy: 0.9639
# 31/93 [=========>....................] - ETA: 2:02 - loss: 0.1123 - accuracy: 0.9633
# 32/93 [=========>....................] - ETA: 2:00 - loss: 0.1137 - accuracy: 0.9630
# 33/93 [=========>....................] - ETA: 1:58 - loss: 0.1134 - accuracy: 0.9628
# 34/93 [=========>....................] - ETA: 1:55 - loss: 0.1134 - accuracy: 0.9628
# 35/93 [==========>...................] - ETA: 1:53 - loss: 0.1127 - accuracy: 0.9632
# 36/93 [==========>...................] - ETA: 1:51 - loss: 0.1118 - accuracy: 0.9635
# 37/93 [==========>...................] - ETA: 1:49 - loss: 0.1120 - accuracy: 0.9635
# 38/93 [===========>..................] - ETA: 1:47 - loss: 0.1116 - accuracy: 0.9634
# 39/93 [===========>..................] - ETA: 1:45 - loss: 0.1138 - accuracy: 0.9626
# 40/93 [===========>..................] - ETA: 1:43 - loss: 0.1131 - accuracy: 0.9627
# 41/93 [============>.................] - ETA: 1:41 - loss: 0.1122 - accuracy: 0.9629
# 42/93 [============>.................] - ETA: 1:39 - loss: 0.1118 - accuracy: 0.9628
# 43/93 [============>.................] - ETA: 1:37 - loss: 0.1109 - accuracy: 0.9633
# 44/93 [=============>................] - ETA: 1:35 - loss: 0.1113 - accuracy: 0.9630
# 45/93 [=============>................] - ETA: 1:33 - loss: 0.1117 - accuracy: 0.9628
# 46/93 [=============>................] - ETA: 1:31 - loss: 0.1108 - accuracy: 0.9633
# 47/93 [==============>...............] - ETA: 1:29 - loss: 0.1099 - accuracy: 0.9637
# 48/93 [==============>...............] - ETA: 1:27 - loss: 0.1097 - accuracy: 0.9637
# 49/93 [==============>...............] - ETA: 1:25 - loss: 0.1092 - accuracy: 0.9640
# 50/93 [===============>..............] - ETA: 1:23 - loss: 0.1090 - accuracy: 0.9641
# 51/93 [===============>..............] - ETA: 1:21 - loss: 0.1088 - accuracy: 0.9638
# 52/93 [===============>..............] - ETA: 1:19 - loss: 0.1090 - accuracy: 0.9639
# 53/93 [================>.............] - ETA: 1:17 - loss: 0.1084 - accuracy: 0.9640
# 54/93 [================>.............] - ETA: 1:15 - loss: 0.1078 - accuracy: 0.9641
# 55/93 [================>.............] - ETA: 1:13 - loss: 0.1080 - accuracy: 0.9641
# 56/93 [=================>............] - ETA: 1:11 - loss: 0.1079 - accuracy: 0.9641
# 57/93 [=================>............] - ETA: 1:09 - loss: 0.1072 - accuracy: 0.9642
# 58/93 [=================>............] - ETA: 1:07 - loss: 0.1074 - accuracy: 0.9642
# 59/93 [==================>...........] - ETA: 1:05 - loss: 0.1080 - accuracy: 0.9640
# 60/93 [==================>...........] - ETA: 1:03 - loss: 0.1076 - accuracy: 0.9641
# 61/93 [==================>...........] - ETA: 1:01 - loss: 0.1083 - accuracy: 0.9641
# 62/93 [===================>..........] - ETA: 59s - loss: 0.1083 - accuracy: 0.9639
# 63/93 [===================>..........] - ETA: 57s - loss: 0.1078 - accuracy: 0.9640
# 64/93 [===================>..........] - ETA: 55s - loss: 0.1077 - accuracy: 0.9639
# 65/93 [===================>..........] - ETA: 53s - loss: 0.1082 - accuracy: 0.9638
# 66/93 [====================>.........] - ETA: 51s - loss: 0.1092 - accuracy: 0.9635
# 67/93 [====================>.........] - ETA: 49s - loss: 0.1092 - accuracy: 0.9633
# 68/93 [====================>.........] - ETA: 48s - loss: 0.1096 - accuracy: 0.9633
# 69/93 [=====================>........] - ETA: 46s - loss: 0.1099 - accuracy: 0.9632
# 70/93 [=====================>........] - ETA: 44s - loss: 0.1098 - accuracy: 0.9631
# 71/93 [=====================>........] - ETA: 42s - loss: 0.1095 - accuracy: 0.9632
# 72/93 [======================>.......] - ETA: 40s - loss: 0.1102 - accuracy: 0.9631
# 73/93 [======================>.......] - ETA: 38s - loss: 0.1100 - accuracy: 0.9632
# 74/93 [======================>.......] - ETA: 36s - loss: 0.1097 - accuracy: 0.9632
# 75/93 [=======================>......] - ETA: 34s - loss: 0.1092 - accuracy: 0.9634
# 76/93 [=======================>......] - ETA: 32s - loss: 0.1096 - accuracy: 0.9632
# 77/93 [=======================>......] - ETA: 30s - loss: 0.1091 - accuracy: 0.9633
# 78/93 [========================>.....] - ETA: 28s - loss: 0.1096 - accuracy: 0.9631
# 79/93 [========================>.....] - ETA: 26s - loss: 0.1093 - accuracy: 0.9632
# 80/93 [========================>.....] - ETA: 24s - loss: 0.1094 - accuracy: 0.9631
# 81/93 [=========================>....] - ETA: 22s - loss: 0.1094 - accuracy: 0.9630
# 82/93 [=========================>....] - ETA: 20s - loss: 0.1093 - accuracy: 0.9630
# 83/93 [=========================>....] - ETA: 19s - loss: 0.1092 - accuracy: 0.9631
# 84/93 [==========================>...] - ETA: 17s - loss: 0.1090 - accuracy: 0.9632
# 85/93 [==========================>...] - ETA: 15s - loss: 0.1091 - accuracy: 0.9630
# 86/93 [==========================>...] - ETA: 13s - loss: 0.1086 - accuracy: 0.9633
# 87/93 [===========================>..] - ETA: 11s - loss: 0.1089 - accuracy: 0.9632
# 88/93 [===========================>..] - ETA: 9s - loss: 0.1092 - accuracy: 0.9630
# 89/93 [===========================>..] - ETA: 7s - loss: 0.1087 - accuracy: 0.9630
# 90/93 [============================>.] - ETA: 5s - loss: 0.1086 - accuracy: 0.9632
# 91/93 [============================>.] - ETA: 3s - loss: 0.1090 - accuracy: 0.9630
# 92/93 [============================>.] - ETA: 1s - loss: 0.1086 - accuracy: 0.9631
# (Worker pid=1981) 2022-07-01 07:43:07.408936: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - ETA: 0s - loss: 0.1081 - accuracy: 0.9632
# 93/93 [==============================] - 182s 2s/step - loss: 0.1081 - accuracy: 0.9632 - val_loss: 0.5402 - val_accuracy: 0.8559
# (Worker pid=1981) Epoch 40/40
#  1/93 [..............................] - ETA: 2:55 - loss: 0.1250 - accuracy: 0.9570
#  2/93 [..............................] - ETA: 2:50 - loss: 0.1245 - accuracy: 0.9590
#  3/93 [..............................] - ETA: 2:44 - loss: 0.1284 - accuracy: 0.9596
#  4/93 [>.............................] - ETA: 2:41 - loss: 0.1292 - accuracy: 0.9609
#  5/93 [>.............................] - ETA: 2:42 - loss: 0.1247 - accuracy: 0.9594
#  6/93 [>.............................] - ETA: 2:41 - loss: 0.1161 - accuracy: 0.9629
#  7/93 [=>............................] - ETA: 2:39 - loss: 0.1111 - accuracy: 0.9654
#  8/93 [=>............................] - ETA: 2:38 - loss: 0.1045 - accuracy: 0.9678
#  9/93 [=>............................] - ETA: 2:36 - loss: 0.1067 - accuracy: 0.9666
# 10/93 [==>...........................] - ETA: 2:34 - loss: 0.1051 - accuracy: 0.9664
# 11/93 [==>...........................] - ETA: 2:32 - loss: 0.1045 - accuracy: 0.9659
# 12/93 [==>...........................] - ETA: 2:31 - loss: 0.1049 - accuracy: 0.9661
# 13/93 [===>..........................] - ETA: 2:29 - loss: 0.1028 - accuracy: 0.9672
# 14/93 [===>..........................] - ETA: 2:27 - loss: 0.1041 - accuracy: 0.9657
# 15/93 [===>..........................] - ETA: 2:25 - loss: 0.1040 - accuracy: 0.9651
# 16/93 [====>.........................] - ETA: 2:23 - loss: 0.1077 - accuracy: 0.9641
# 17/93 [====>.........................] - ETA: 2:21 - loss: 0.1054 - accuracy: 0.9648
# 18/93 [====>.........................] - ETA: 2:19 - loss: 0.1041 - accuracy: 0.9648
# 19/93 [=====>........................] - ETA: 2:18 - loss: 0.1043 - accuracy: 0.9646
# 20/93 [=====>........................] - ETA: 2:15 - loss: 0.1046 - accuracy: 0.9641
# 21/93 [=====>........................] - ETA: 2:14 - loss: 0.1060 - accuracy: 0.9641
# 22/93 [======>.......................] - ETA: 2:12 - loss: 0.1066 - accuracy: 0.9641
# 23/93 [======>.......................] - ETA: 2:10 - loss: 0.1079 - accuracy: 0.9637
# 24/93 [======>.......................] - ETA: 2:08 - loss: 0.1074 - accuracy: 0.9635
# 25/93 [=======>......................] - ETA: 2:06 - loss: 0.1085 - accuracy: 0.9634
# 26/93 [=======>......................] - ETA: 2:05 - loss: 0.1084 - accuracy: 0.9639
# 27/93 [=======>......................] - ETA: 2:03 - loss: 0.1089 - accuracy: 0.9637
# 28/93 [========>.....................] - ETA: 2:01 - loss: 0.1073 - accuracy: 0.9640
# 29/93 [========>.....................] - ETA: 1:59 - loss: 0.1055 - accuracy: 0.9646
# 30/93 [========>.....................] - ETA: 1:57 - loss: 0.1055 - accuracy: 0.9646
# 31/93 [=========>....................] - ETA: 1:55 - loss: 0.1050 - accuracy: 0.9646
# 32/93 [=========>....................] - ETA: 1:53 - loss: 0.1055 - accuracy: 0.9646
# 33/93 [=========>....................] - ETA: 1:52 - loss: 0.1063 - accuracy: 0.9645
# 34/93 [=========>....................] - ETA: 1:51 - loss: 0.1050 - accuracy: 0.9651
# 35/93 [==========>...................] - ETA: 1:53 - loss: 0.1054 - accuracy: 0.9650
# 36/93 [==========>...................] - ETA: 1:56 - loss: 0.1051 - accuracy: 0.9650
# 37/93 [==========>...................] - ETA: 2:00 - loss: 0.1049 - accuracy: 0.9653
# 38/93 [===========>..................] - ETA: 2:02 - loss: 0.1045 - accuracy: 0.9653
# 39/93 [===========>..................] - ETA: 2:04 - loss: 0.1045 - accuracy: 0.9654
# 40/93 [===========>..................] - ETA: 2:03 - loss: 0.1045 - accuracy: 0.9653
# 41/93 [============>.................] - ETA: 2:02 - loss: 0.1048 - accuracy: 0.9656
# 42/93 [============>.................] - ETA: 2:00 - loss: 0.1044 - accuracy: 0.9658
# 43/93 [============>.................] - ETA: 1:59 - loss: 0.1043 - accuracy: 0.9657
# 44/93 [=============>................] - ETA: 1:59 - loss: 0.1059 - accuracy: 0.9653
# 45/93 [=============>................] - ETA: 1:57 - loss: 0.1067 - accuracy: 0.9655
# 46/93 [=============>................] - ETA: 1:55 - loss: 0.1078 - accuracy: 0.9652
# 47/93 [==============>...............] - ETA: 1:54 - loss: 0.1074 - accuracy: 0.9652
# 48/93 [==============>...............] - ETA: 1:51 - loss: 0.1077 - accuracy: 0.9650
# 49/93 [==============>...............] - ETA: 1:48 - loss: 0.1079 - accuracy: 0.9648
# 50/93 [===============>..............] - ETA: 1:45 - loss: 0.1086 - accuracy: 0.9645
# 51/93 [===============>..............] - ETA: 1:42 - loss: 0.1080 - accuracy: 0.9649
# 52/93 [===============>..............] - ETA: 1:39 - loss: 0.1068 - accuracy: 0.9654
# 53/93 [================>.............] - ETA: 1:36 - loss: 0.1063 - accuracy: 0.9655
# 54/93 [================>.............] - ETA: 1:34 - loss: 0.1058 - accuracy: 0.9657
# 55/93 [================>.............] - ETA: 1:31 - loss: 0.1056 - accuracy: 0.9657
# 56/93 [=================>............] - ETA: 1:28 - loss: 0.1059 - accuracy: 0.9655
# 57/93 [=================>............] - ETA: 1:25 - loss: 0.1055 - accuracy: 0.9655
# 58/93 [=================>............] - ETA: 1:23 - loss: 0.1049 - accuracy: 0.9656
# 59/93 [==================>...........] - ETA: 1:21 - loss: 0.1043 - accuracy: 0.9658
# 60/93 [==================>...........] - ETA: 1:18 - loss: 0.1043 - accuracy: 0.9658
# 61/93 [==================>...........] - ETA: 1:15 - loss: 0.1043 - accuracy: 0.9657
# 62/93 [===================>..........] - ETA: 1:13 - loss: 0.1045 - accuracy: 0.9655
# 63/93 [===================>..........] - ETA: 1:10 - loss: 0.1044 - accuracy: 0.9655
# 64/93 [===================>..........] - ETA: 1:08 - loss: 0.1042 - accuracy: 0.9658
# 65/93 [===================>..........] - ETA: 1:05 - loss: 0.1039 - accuracy: 0.9657
# 66/93 [====================>.........] - ETA: 1:02 - loss: 0.1045 - accuracy: 0.9654
# 67/93 [====================>.........] - ETA: 1:00 - loss: 0.1042 - accuracy: 0.9655
# 68/93 [====================>.........] - ETA: 58s - loss: 0.1037 - accuracy: 0.9657
# 69/93 [=====================>........] - ETA: 55s - loss: 0.1037 - accuracy: 0.9656
# 70/93 [=====================>........] - ETA: 53s - loss: 0.1035 - accuracy: 0.9657
# 71/93 [=====================>........] - ETA: 50s - loss: 0.1026 - accuracy: 0.9659
# 72/93 [======================>.......] - ETA: 48s - loss: 0.1028 - accuracy: 0.9659
# 73/93 [======================>.......] - ETA: 45s - loss: 0.1026 - accuracy: 0.9659
# 74/93 [======================>.......] - ETA: 43s - loss: 0.1028 - accuracy: 0.9657
# 75/93 [=======================>......] - ETA: 41s - loss: 0.1027 - accuracy: 0.9659
# 76/93 [=======================>......] - ETA: 38s - loss: 0.1025 - accuracy: 0.9659
# 77/93 [=======================>......] - ETA: 36s - loss: 0.1023 - accuracy: 0.9661
# 78/93 [========================>.....] - ETA: 34s - loss: 0.1031 - accuracy: 0.9658
# 79/93 [========================>.....] - ETA: 32s - loss: 0.1029 - accuracy: 0.9657
# 80/93 [========================>.....] - ETA: 29s - loss: 0.1030 - accuracy: 0.9657
# 81/93 [=========================>....] - ETA: 27s - loss: 0.1028 - accuracy: 0.9658
# 82/93 [=========================>....] - ETA: 25s - loss: 0.1028 - accuracy: 0.9658
# 83/93 [=========================>....] - ETA: 22s - loss: 0.1025 - accuracy: 0.9659
# 84/93 [==========================>...] - ETA: 20s - loss: 0.1023 - accuracy: 0.9660
# 85/93 [==========================>...] - ETA: 18s - loss: 0.1019 - accuracy: 0.9661
# 86/93 [==========================>...] - ETA: 15s - loss: 0.1017 - accuracy: 0.9661
# 87/93 [===========================>..] - ETA: 13s - loss: 0.1014 - accuracy: 0.9662
# 88/93 [===========================>..] - ETA: 11s - loss: 0.1012 - accuracy: 0.9663
# 89/93 [===========================>..] - ETA: 9s - loss: 0.1012 - accuracy: 0.9662
# 90/93 [============================>.] - ETA: 6s - loss: 0.1010 - accuracy: 0.9662
# 91/93 [============================>.] - ETA: 4s - loss: 0.1012 - accuracy: 0.9660
# 92/93 [============================>.] - ETA: 2s - loss: 0.1009 - accuracy: 0.9662
# 93/93 [==============================] - ETA: 0s - loss: 0.1013 - accuracy: 0.9661
# (Worker pid=1981) 2022-07-01 07:46:40.252150: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
# 93/93 [==============================] - 213s 2s/step - loss: 0.1013 - accuracy: 0.9661 - val_loss: 0.5492 - val_accuracy: 0.8582

# %%
import pathlib
pathlib.Path("/content/drive/MyDrive/Colab/BigData/model").mkdir(parents=True, exist_ok=True)
est.save("/content/drive/MyDrive/Colab/BigData/model/vihsd_keras_gru.ckpt")
# Out:
# '/content/drive/MyDrive/Colab/BigData/model/vihsd_keras_gru.ckpt'

# %% [markdown]
# Finally, evaluate using the Estimator.

# %%
result = est.evaluate(
    df_test_clean,
    feature_cols=['text_encoded'],
    label_cols=['label_encoded'],
    num_steps=10000 // batch_size
)
print(result)
# Out:
# (Worker pid=1981) 2022-07-01 07:48:03.521955: W tensorflow/core/framework/dataset.cc:768] Input of GeneratorDatasetOp::Dataset will not be optimized because the dataset does not implement the AsGraphDefInternal() method needed to apply optimizations.
#  1/39 [..............................] - ETA: 7s - loss: 1.1982 - accuracy: 0.7188
#  2/39 [>.............................] - ETA: 3s - loss: 0.8637 - accuracy: 0.7969
#  3/39 [=>............................] - ETA: 3s - loss: 0.7087 - accuracy: 0.8125
#  4/39 [==>...........................] - ETA: 3s - loss: 0.5985 - accuracy: 0.8438
#  6/39 [===>..........................] - ETA: 3s - loss: 0.6397 - accuracy: 0.8490
#  7/39 [====>.........................] - ETA: 2s - loss: 0.6466 - accuracy: 0.8482
#  8/39 [=====>........................] - ETA: 2s - loss: 0.6621 - accuracy: 0.8398
# 10/39 [======>.......................] - ETA: 2s - loss: 0.5937 - accuracy: 0.8500
# 11/39 [=======>......................] - ETA: 2s - loss: 0.6050 - accuracy: 0.8523
# 12/39 [========>.....................] - ETA: 2s - loss: 0.6059 - accuracy: 0.8542
# 13/39 [=========>....................] - ETA: 2s - loss: 0.5623 - accuracy: 0.8654
# 14/39 [=========>....................] - ETA: 2s - loss: 0.6034 - accuracy: 0.8594
# 15/39 [==========>...................] - ETA: 2s - loss: 0.5914 - accuracy: 0.8604
# 16/39 [===========>..................] - ETA: 2s - loss: 0.6116 - accuracy: 0.8574
# 18/39 [============>.................] - ETA: 1s - loss: 0.6011 - accuracy: 0.8576
# 19/39 [=============>................] - ETA: 1s - loss: 0.6089 - accuracy: 0.8536
# 21/39 [===============>..............] - ETA: 1s - loss: 0.5940 - accuracy: 0.8497
# 22/39 [===============>..............] - ETA: 1s - loss: 0.5785 - accuracy: 0.8523
# 23/39 [================>.............] - ETA: 1s - loss: 0.6054 - accuracy: 0.8451
# 24/39 [=================>............] - ETA: 1s - loss: 0.5962 - accuracy: 0.8464
# 25/39 [==================>...........] - ETA: 1s - loss: 0.5975 - accuracy: 0.8487
# 26/39 [===================>..........] - ETA: 1s - loss: 0.5935 - accuracy: 0.8498
# 27/39 [===================>..........] - ETA: 1s - loss: 0.6012 - accuracy: 0.8495
# 28/39 [====================>.........] - ETA: 0s - loss: 0.5964 - accuracy: 0.8504
# 29/39 [=====================>........] - ETA: 0s - loss: 0.5976 - accuracy: 0.8481
# 30/39 [======================>.......] - ETA: 0s - loss: 0.5937 - accuracy: 0.8479
# 31/39 [======================>.......] - ETA: 0s - loss: 0.5982 - accuracy: 0.8488
# 32/39 [=======================>......] - ETA: 0s - loss: 0.5905 - accuracy: 0.8496
# 34/39 [=========================>....] - ETA: 0s - loss: 0.5960 - accuracy: 0.8456
# 35/39 [=========================>....] - ETA: 0s - loss: 0.5900 - accuracy: 0.8464
# 36/39 [==========================>...] - ETA: 0s - loss: 0.5878 - accuracy: 0.8472
# 37/39 [===========================>..] - ETA: 0s - loss: 0.5772 - accuracy: 0.8488
# 38/39 [============================>.] - ETA: 0s - loss: 0.5685 - accuracy: 0.8503
# 39/39 [==============================] - 4s 91ms/step - loss: 0.5732 - accuracy: 0.8486
# [{'validation_loss': 0.5732230544090271, 'validation_accuracy': 0.848557710647583}]

# %%
predictions = est.predict(data=df_test_clean, feature_cols=['text_encoded'])
# Out:
#   1/209 [..............................] - ETA: 5:39
#   2/209 [..............................] - ETA: 20s
#   3/209 [..............................] - ETA: 21s
#   4/209 [..............................] - ETA: 21s
#   5/209 [..............................] - ETA: 22s
#   6/209 [..............................] - ETA: 21s
#   7/209 [>.............................] - ETA: 21s
#   8/209 [>.............................] - ETA: 21s
#   9/209 [>.............................] - ETA: 20s
#  10/209 [>.............................] - ETA: 20s
#  11/209 [>.............................] - ETA: 20s
#  12/209 [>.............................] - ETA: 20s
#  13/209 [>.............................] - ETA: 20s
#  14/209 [=>............................] - ETA: 19s
#  15/209 [=>............................] - ETA: 20s
#  16/209 [=>............................] - ETA: 20s
#  17/209 [=>............................] - ETA: 21s
#  18/209 [=>............................] - ETA: 21s
#  19/209 [=>............................] - ETA: 22s
#  20/209 [=>............................] - ETA: 23s
#  21/209 [==>...........................] - ETA: 24s
#  22/209 [==>...........................] - ETA: 24s
#  23/209 [==>...........................] - ETA: 26s
#  24/209 [==>...........................] - ETA: 26s
#  25/209 [==>...........................] - ETA: 28s
#  26/209 [==>...........................] - ETA: 28s
#  27/209 [==>...........................] - ETA: 29s
#  28/209 [===>..........................] - ETA: 29s
#  29/209 [===>..........................] - ETA: 29s
#  30/209 [===>..........................] - ETA: 30s
#  31/209 [===>..........................] - ETA: 29s
#  32/209 [===>..........................] - ETA: 30s
#  33/209 [===>..........................] - ETA: 30s
#  34/209 [===>..........................] - ETA: 31s
#  35/209 [====>.........................] - ETA: 30s
#  36/209 [====>.........................] - ETA: 30s
#  37/209 [====>.........................] - ETA: 31s
#  38/209 [====>.........................] - ETA: 31s
#  39/209 [====>.........................] - ETA: 31s
#  40/209 [====>.........................] - ETA: 31s
#  41/209 [====>.........................] - ETA: 30s
#  42/209 [=====>........................] - ETA: 30s
#  43/209 [=====>........................] - ETA: 30s
#  44/209 [=====>........................] - ETA: 30s
#  45/209 [=====>........................] - ETA: 30s
#  46/209 [=====>........................] - ETA: 29s
#  47/209 [=====>........................] - ETA: 29s
#  48/209 [=====>........................] - ETA: 29s
#  49/209 [======>.......................] - ETA: 29s
#  50/209 [======>.......................] - ETA: 29s
#  51/209 [======>.......................] - ETA: 29s
#  52/209 [======>.......................] - ETA: 28s
#  53/209 [======>.......................] - ETA: 28s
#  54/209 [======>.......................] - ETA: 27s
#  55/209 [======>.......................] - ETA: 27s
#  56/209 [=======>......................] - ETA: 26s
#  57/209 [=======>......................] - ETA: 26s
#  58/209 [=======>......................] - ETA: 26s
#  59/209 [=======>......................] - ETA: 25s
#  60/209 [=======>......................] - ETA: 25s
#  61/209 [=======>......................] - ETA: 25s
#  62/209 [=======>......................] - ETA: 24s
#  63/209 [========>.....................] - ETA: 24s
#  64/209 [========>.....................] - ETA: 24s
#  66/209 [========>.....................] - ETA: 23s
#  67/209 [========>.....................] - ETA: 23s
#  68/209 [========>.....................] - ETA: 23s
#  69/209 [========>.....................] - ETA: 22s
#  70/209 [=========>....................] - ETA: 22s
#  71/209 [=========>....................] - ETA: 22s
#  73/209 [=========>....................] - ETA: 21s
#  75/209 [=========>....................] - ETA: 21s
#  76/209 [=========>....................] - ETA: 20s
#  77/209 [==========>...................] - ETA: 20s
#  78/209 [==========>...................] - ETA: 20s
#  79/209 [==========>...................] - ETA: 20s
#  80/209 [==========>...................] - ETA: 19s
#  81/209 [==========>...................] - ETA: 19s
#  82/209 [==========>...................] - ETA: 19s
#  83/209 [==========>...................] - ETA: 19s
#  84/209 [===========>..................] - ETA: 18s
#  85/209 [===========>..................] - ETA: 18s
#  87/209 [===========>..................] - ETA: 18s
#  88/209 [===========>..................] - ETA: 18s
#  89/209 [===========>..................] - ETA: 17s
#  90/209 [===========>..................] - ETA: 17s
#  91/209 [============>.................] - ETA: 17s
#  92/209 [============>.................] - ETA: 17s
#  93/209 [============>.................] - ETA: 17s
#  94/209 [============>.................] - ETA: 16s
#  95/209 [============>.................] - ETA: 16s
#  96/209 [============>.................] - ETA: 16s
#  97/209 [============>.................] - ETA: 16s
#  98/209 [=============>................] - ETA: 16s
#  99/209 [=============>................] - ETA: 15s
# 100/209 [=============>................] - ETA: 15s
# 101/209 [=============>................] - ETA: 15s
# 102/209 [=============>................] - ETA: 15s
# 103/209 [=============>................] - ETA: 15s
# 104/209 [=============>................] - ETA: 15s
# 105/209 [==============>...............] - ETA: 14s
# 106/209 [==============>...............] - ETA: 14s
# 107/209 [==============>...............] - ETA: 14s
# 108/209 [==============>...............] - ETA: 14s
# 110/209 [==============>...............] - ETA: 13s
# 111/209 [==============>...............] - ETA: 13s
# 112/209 [===============>..............] - ETA: 13s
# 113/209 [===============>..............] - ETA: 13s
# 114/209 [===============>..............] - ETA: 13s
# 115/209 [===============>..............] - ETA: 13s
# 116/209 [===============>..............] - ETA: 12s
# 117/209 [===============>..............] - ETA: 12s
# 118/209 [===============>..............] - ETA: 12s
# 119/209 [================>.............] - ETA: 12s
# 120/209 [================>.............] - ETA: 12s
# 121/209 [================>.............] - ETA: 12s
# 122/209 [================>.............] - ETA: 11s
# 123/209 [================>.............] - ETA: 11s
# 124/209 [================>.............] - ETA: 11s
# 125/209 [================>.............] - ETA: 11s
# 126/209 [=================>............] - ETA: 11s
# 127/209 [=================>............] - ETA: 11s
# 128/209 [=================>............] - ETA: 11s
# 129/209 [=================>............] - ETA: 10s
# 130/209 [=================>............] - ETA: 10s
# 131/209 [=================>............] - ETA: 10s
# 132/209 [=================>............] - ETA: 10s
# 133/209 [==================>...........] - ETA: 10s
# 134/209 [==================>...........] - ETA: 10s
# 135/209 [==================>...........] - ETA: 9s
# 136/209 [==================>...........] - ETA: 9s
# 137/209 [==================>...........] - ETA: 9s
# 138/209 [==================>...........] - ETA: 9s
# 139/209 [==================>...........] - ETA: 9s
# 140/209 [===================>..........] - ETA: 9s
# 142/209 [===================>..........] - ETA: 8s
# 143/209 [===================>..........] - ETA: 8s
# 144/209 [===================>..........] - ETA: 8s
# 145/209 [===================>..........] - ETA: 8s
# 146/209 [===================>..........] - ETA: 8s
# 147/209 [====================>.........] - ETA: 8s
# 148/209 [====================>.........] - ETA: 8s
# 149/209 [====================>.........] - ETA: 7s
# 150/209 [====================>.........] - ETA: 7s
# 151/209 [====================>.........] - ETA: 7s
# 152/209 [====================>.........] - ETA: 7s
# 153/209 [====================>.........] - ETA: 7s
# 154/209 [=====================>........] - ETA: 7s
# 155/209 [=====================>........] - ETA: 7s
# 156/209 [=====================>........] - ETA: 6s
# 157/209 [=====================>........] - ETA: 6s
# 158/209 [=====================>........] - ETA: 6s
# 159/209 [=====================>........] - ETA: 6s
# 160/209 [=====================>........] - ETA: 6s
# 161/209 [======================>.......] - ETA: 6s
# 162/209 [======================>.......] - ETA: 6s
# 163/209 [======================>.......] - ETA: 5s
# 164/209 [======================>.......] - ETA: 5s
# 165/209 [======================>.......] - ETA: 5s
# 166/209 [======================>.......] - ETA: 5s
# 167/209 [======================>.......] - ETA: 5s
# 168/209 [=======================>......] - ETA: 5s
# 169/209 [=======================>......] - ETA: 5s
# 170/209 [=======================>......] - ETA: 5s
# 171/209 [=======================>......] - ETA: 4s
# 172/209 [=======================>......] - ETA: 4s
# 173/209 [=======================>......] - ETA: 4s
# 174/209 [=======================>......] - ETA: 4s
# 175/209 [========================>.....] - ETA: 4s
# 176/209 [========================>.....] - ETA: 4s
# 177/209 [========================>.....] - ETA: 4s
# 178/209 [========================>.....] - ETA: 3s
# 179/209 [========================>.....] - ETA: 3s
# 180/209 [========================>.....] - ETA: 3s
# 181/209 [========================>.....] - ETA: 3s
# 182/209 [=========================>....] - ETA: 3s
# 183/209 [=========================>....] - ETA: 3s
# 184/209 [=========================>....] - ETA: 3s
# 185/209 [=========================>....] - ETA: 3s
# 186/209 [=========================>....] - ETA: 2s
# 187/209 [=========================>....] - ETA: 2s
# 188/209 [=========================>....] - ETA: 2s
# 189/209 [==========================>...] - ETA: 2s
# 190/209 [==========================>...] - ETA: 2s
# 191/209 [==========================>...] - ETA: 2s
# 192/209 [==========================>...] - ETA: 2s
# 193/209 [==========================>...] - ETA: 2s
# 194/209 [==========================>...] - ETA: 1s
# 195/209 [==========================>...] - ETA: 1s
# 196/209 [===========================>..] - ETA: 1s
# 197/209 [===========================>..] - ETA: 1s
# 198/209 [===========================>..] - ETA: 1s
# 199/209 [===========================>..] - ETA: 1s
# 200/209 [===========================>..] - ETA: 1s
# 201/209 [===========================>..] - ETA: 0s
# 203/209 [============================>.] - ETA: 0s
# 204/209 [============================>.] - ETA: 0s
# 205/209 [============================>.] - ETA: 0s
# 206/209 [============================>.] - ETA: 0s
# 207/209 [============================>.] - ETA: 0s
# 208/209 [============================>.] - ETA: 0s
# 209/209 [==============================] - 27s 124ms/step

# %%
predictions.select('text', 'label_encoded', 'prediction').show(30, truncate=True)
# Out:
# +--------------------+---------------+--------------------+
# |                text|  label_encoded|          prediction|
# +--------------------+---------------+--------------------+
# |đừng cố biện_minh...|[1.0, 0.0, 0.0]|[0.021763837, 0.1...|
# |haizz . nthe dân khổ|[0.0, 1.0, 0.0]|[0.9801932, 0.012...|
# |the ma chi phat g...|[1.0, 0.0, 0.0]|[0.4365628, 0.528...|
# |mua hộp bcs mĩ sà...|[1.0, 0.0, 0.0]|[0.1688415, 0.449...|
# |       coin card : 3|[0.0, 1.0, 0.0]|[0.9988312, 7.471...|
# |k dừng hả trời ☹ ...|[1.0, 0.0, 0.0]|[0.9999212, 6.952...|
# |               : ) )|[1.0, 0.0, 0.0]|[0.98806274, 0.00...|
# |            chi chui|[1.0, 0.0, 0.0]|[0.99624205, 0.00...|
# |     lê văn quật vid|[1.0, 0.0, 0.0]|[0.9995096, 3.605...|
# |       lý khùng , kk|[1.0, 0.0, 0.0]|[0.9326682, 0.009...|
# |nhật chẳng hợn võ...|[1.0, 0.0, 0.0]|[0.9957503, 0.003...|
# |     thầy trêu lắm r|[1.0, 0.0, 0.0]|[0.99967873, 5.38...|
# |         ôi tuổi_thơ|[1.0, 0.0, 0.0]|[0.9993425, 5.611...|
# |hang luc nao cung...|[1.0, 0.0, 0.0]|[0.9992747, 5.491...|
# |lee shung liem ye...|[1.0, 0.0, 0.0]|[0.9992762, 6.344...|
# |set đồ vận_động_v...|[1.0, 0.0, 0.0]|[0.39791456, 0.13...|
# |            thay ngu|[0.0, 0.0, 1.0]|[0.40986687, 0.11...|
# |          đc đấy abe|[1.0, 0.0, 0.0]|[0.99628097, 0.00...|
# |hóng 2 hài hải ng...|[1.0, 0.0, 0.0]|[0.9997967, 8.818...|
# |sét đánh chết tao đi|[1.0, 0.0, 0.0]|[0.67376477, 0.23...|
# |       khỏe_idol tui|[1.0, 0.0, 0.0]|[0.99631846, 0.00...|
# |gia_thế giàu khổ ...|[1.0, 0.0, 0.0]|[0.99642545, 6.22...|
# |( y ) page ad kiế...|[0.0, 0.0, 1.0]|[0.9982127, 3.460...|
# |đề_nghị 17 , 22,2...|[0.0, 0.0, 1.0]|[0.9996101, 2.873...|
# |trường_học , cầu_...|[1.0, 0.0, 0.0]|[0.09060321, 0.02...|
# |             a n vl |[1.0, 0.0, 0.0]|[0.7962183, 0.200...|
# |hoàng_yến fan cứn...|[1.0, 0.0, 0.0]|[0.9999008, 3.920...|
# | from bình phước < 3|[1.0, 0.0, 0.0]|[0.9996635, 1.608...|
# |mong thầy đóng mv...|[1.0, 0.0, 0.0]|[0.9965312, 5.673...|
# |           tấu hài  |[1.0, 0.0, 0.0]|[0.9995034, 2.670...|
# +--------------------+---------------+--------------------+
# only showing top 30 rows

# %%
to_array = f.udf(lambda v: v.toArray().tolist(), t.ArrayType(t.FloatType()))
predictions = predictions.withColumn('prediction', to_array('prediction'))

# %%
pd_prediction = predictions.select(
    'label_id',
    f.expr('array_position(cast(prediction as array<float>), cast(array_max(prediction) as float)) - 1').alias("label_predict")
).toPandas()

# %%
y_true = pd_prediction['label_id']
y_pred = pd_prediction['label_predict']

f1_micro = f1_score(y_true, y_pred, average='micro')
f1_macro = f1_score(y_true, y_pred, average='macro')
accuracy = accuracy_score(y_true, y_pred)

print(f"F1 - micro: {f1_score}")
print(f"F1 - macro: {f1_macro}")
print(f"Accuracy: {accuracy}")

cf = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf, index = ["clean", "offensive", "hate"], columns = ["clean", "offensive", "hate"])
sn.heatmap(df_cm, annot=True, cmap="Greys",fmt='g', cbar=True, annot_kws={"size": 28})
# Out:
# F1 - micro: <function f1_score at 0x7fb1a142f7a0>
# F1 - macro: 0.5946472378477349
# Accuracy: 0.8534431137724551

# %%
est.shutdown()

# %%
print(stats)

# %% [markdown]
# Now, the accuracy of this model has reached 98%.

# %%
# Stop orca context when your program finishes
stop_orca_context()
